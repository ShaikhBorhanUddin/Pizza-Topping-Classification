# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
dataset_path = '/content/drive/My Drive/Pizza Topping Classification Project/Pizza_classification_Dataset'

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.convnext import preprocess_input
IMG_SIZE = (224, 224)
BATCH_SIZE = 256

# Data augmentation and preprocessing (ConvNeXtBase preprocessing)
datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True,
    validation_split=0.1
)

# Load training data
train_generator = datagen.flow_from_directory(
    '/content/drive/My Drive/Pizza Topping Classification Project/Pizza_Classification_Dataset/train',
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    subset='training',
)

# Load validation data
validation_generator = datagen.flow_from_directory(
    '/content/drive/My Drive/Pizza Topping Classification Project/Pizza_Classification_Dataset/train',
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    subset='validation',
)
# Load and preprocess test images
test_generator = datagen.flow_from_directory(
    '/content/drive/My Drive/Pizza Topping Classification Project/Pizza_Classification_Dataset/test',  # Path to the test dataset
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical'
)
# Out:
# Found 1703 images belonging to 3 classes.
# Found 188 images belonging to 3 classes.
# Found 473 images belonging to 3 classes.

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd

# Define your data paths
train_data_path = '/content/drive/My Drive/Pizza Topping Classification Project/Pizza_Classification_Dataset/train'
test_data_path = '/content/drive/My Drive/Pizza Topping Classification Project/Pizza_Classification_Dataset/test'

# Define your pizza categories
pizza_categories = ['Basil', 'Mushroom', 'Pepperoni']

# Initialize counts for each category
train_counts = {category: 0 for category in pizza_categories}
test_counts = {category: 0 for category in pizza_categories}

# Count images in train dataset
for category in pizza_categories:
    category_path = os.path.join(train_data_path, category)
    train_counts[category] = len(os.listdir(category_path))

# Count images in test dataset
for category in pizza_categories:
    category_path = os.path.join(test_data_path, category)
    test_counts[category] = len(os.listdir(category_path))

df = pd.DataFrame({
    'Category': pizza_categories,
    'Train Count': list(train_counts.values()),
    'Test Count': list(test_counts.values())
})

# Get the positions for the bars
x = np.arange(len(pizza_categories))
width = 0.35  # Width of the bars

# Create the bar plot
fig, ax = plt.subplots(figsize=(12, 6))
rects1 = ax.bar(x - width/2, df['Train Count'], width, label='Train')
rects2 = ax.bar(x + width/2, df['Test Count'], width, label='Test')

# Add labels, title, and legend
ax.set_xlabel('Pizza Categories')
ax.set_ylabel('Number of Images')
ax.set_title('Image Distribution Across Pizza Categories')
ax.set_xticks(x)
ax.set_xticklabels(pizza_categories)
ax.legend()

# Add count labels using the provided code snippet
for index, row in df.iterrows():
    plt.text(x=index - width/2, y=row['Train Count'] + 10, s=str(row['Train Count']), ha='center', va='bottom', fontsize=10)
    plt.text(x=index + width/2, y=row['Test Count'] + 10, s=str(row['Test Count']), ha='center', va='bottom', fontsize=10)

# Display the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import os
from PIL import Image
import random

def plot_sample_images(img_paths, labels, num_images=5):
    fig, axes = plt.subplots(1, num_images, figsize=(15, 5))
    for i, img_path in enumerate(img_paths[:num_images]):
        img = Image.open(img_path)
        axes[i].imshow(img)
        axes[i].set_title(labels[i])
        axes[i].axis('off')
    plt.show()

# Define your data paths and pizza categories
data_path = '/content/drive/My Drive/Pizza Topping Classification Project/Pizza_Classification_Dataset/train'
pizza_categories = ['Basil', 'Mushroom', 'Pepperoni']

for category in pizza_categories:
    category_path = os.path.join(data_path, category)
    all_img_files = os.listdir(category_path)
    random_img_files = random.sample(all_img_files, 5)
    img_paths = [os.path.join(category_path, img_file) for img_file in random_img_files]
    plot_sample_images(img_paths, [category] * len(img_paths))

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import os
import random

# Define data augmentation
datagen = ImageDataGenerator(
    rescale=1.0/255,  # Normalize pixel values to [0, 1]
    rotation_range=20,  # Add rotation
    width_shift_range=0.2,  # Add width shift
    height_shift_range=0.2, # Add height shift
    horizontal_flip=True,  # Randomly flip images horizontally
    fill_mode='nearest'
)

# Define your data paths and pizza categories
data_path = '/content/drive/My Drive/Pizza Topping Classification Project/Pizza_Classification_Dataset/train'
pizza_categories = ['Basil', 'Mushroom', 'Pepperoni']

# Loop through each pizza category and plot sample images
for category in pizza_categories:
    category_path = os.path.join(data_path, category)

    # Randomly select an image from the directory
    img_name = random.choice(os.listdir(category_path))
    img_path = os.path.join(category_path, img_name)

    # Load a single image and apply augmentation
    img = Image.open(img_path).resize((224, 224))
    img = img.convert('RGB')  # Ensure RGB format
    img = np.array(img)
    img = img.reshape((1, 224, 224, 3))

    # Generate augmented images
    augmented_imgs = [datagen.flow(img, batch_size=1).__next__()[0] for _ in range(5)]

    # Plot original and augmented images
    fig, axes = plt.subplots(1, 6, figsize=(20, 5))
    axes[0].imshow(img[0].astype('uint8'))  # Original image
    axes[0].set_title(f"Original {category} Image")

    for i, aug_img in enumerate(augmented_imgs):
        aug_img = (aug_img * 255).astype('uint8')  # Rescale augmented image to 0-255
        axes[i + 1].imshow(aug_img)
        axes[i + 1].set_title(f"Augmented {category} Image {i+1}")

    plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
from tensorflow.keras.applications import ConvNeXtBase
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.metrics import Precision, Recall
from tensorflow.keras.optimizers import Adam
import tensorflow as tf

# Create Precision and Recall metrics outside the function
precision_metric = Precision()
recall_metric = Recall()

# Custom F1-score metric
def f1_score(y_true, y_pred):
    precision = precision_metric(y_true, y_pred)  # Use pre-created metric
    recall = recall_metric(y_true, y_pred)       # Use pre-created metric
    f1 = 2 * ((precision * recall) / (precision + recall + tf.keras.backend.epsilon()))
    return f1

# Apply mixed precision for faster training and less GPU load
from tensorflow.keras import mixed_precision
mixed_precision.set_global_policy('mixed_float16')

# Load pre-trained ConvNeXtBase model without the top classification layer
base_model = ConvNeXtBase(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Freeze the base model to retain pre-trained weights
base_model.trainable = False

# Add custom classification layers
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(512, activation='relu')(x)
x = Dropout(0.5)(x)
# Apply the output layer to the previous layer's output
output = Dense(3, activation='softmax')(x)  # 3 classes: Basil, Mushroom, Pepperoni

# Create the final model
model = Model(inputs=base_model.input, outputs=output)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/convnext/convnext_base_notop.h5
# 350926856/350926856 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step

# %%
model.summary()
# Out:
# Model: "functional_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)  │ (None, 224, 224, 3)    │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ cast (Cast)               │ (None, 224, 224, 3)    │              0 │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_prestem_no… │ (None, 224, 224, 3)    │              0 │ cast[0][0]             │
# │ (Normalization)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stem        │ (None, 56, 56, 128)    │          6,528 │ convnext_base_prestem… │
# │ (Sequential)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_0_bl… │ (None, 56, 56, 128)    │          6,400 │ convnext_base_stem[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_0_bl… │ (None, 56, 56, 128)    │            256 │ convnext_base_stage_0… │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_0_bl… │ (None, 56, 56, 512)    │         66,048 │ convnext_base_stage_0… │
# │ (Dense)                   │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_0_bl… │ (None, 56, 56, 512)    │              0 │ convnext_base_stage_0… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_0_bl… │ (None, 56, 56, 128)    │         65,664 │ convnext_base_stage_0… │
# │ (Dense)                   │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_0_bl… │ (None, 56, 56, 128)    │            128 │ convnext_base_stage_0… │
# │ (LayerScale)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_0_bl… │ (None, 56, 56, 128)    │              0 │ convnext_base_stage_0… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add (Add)                 │ (None, 56, 56, 128)    │              0 │ convnext_base_stem[0]… │
# │                           │                        │                │ convnext_base_stage_0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_0_bl… │ (None, 56, 56, 128)    │          6,400 │ add[0][0]              │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_0_bl… │ (None, 56, 56, 128)    │            256 │ convnext_base_stage_0… │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_0_bl… │ (None, 56, 56, 512)    │         66,048 │ convnext_base_stage_0… │
# │ (Dense)                   │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_0_bl… │ (None, 56, 56, 512)    │              0 │ convnext_base_stage_0… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_0_bl… │ (None, 56, 56, 128)    │         65,664 │ convnext_base_stage_0… │
# │ (Dense)                   │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_0_bl… │ (None, 56, 56, 128)    │            128 │ convnext_base_stage_0… │
# │ (LayerScale)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_0_bl… │ (None, 56, 56, 128)    │              0 │ convnext_base_stage_0… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_1 (Add)               │ (None, 56, 56, 128)    │              0 │ add[0][0],             │
# │                           │                        │                │ convnext_base_stage_0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_0_bl… │ (None, 56, 56, 128)    │          6,400 │ add_1[0][0]            │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_0_bl… │ (None, 56, 56, 128)    │            256 │ convnext_base_stage_0… │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_0_bl… │ (None, 56, 56, 512)    │         66,048 │ convnext_base_stage_0… │
# │ (Dense)                   │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_0_bl… │ (None, 56, 56, 512)    │              0 │ convnext_base_stage_0… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_0_bl… │ (None, 56, 56, 128)    │         65,664 │ convnext_base_stage_0… │
# │ (Dense)                   │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_0_bl… │ (None, 56, 56, 128)    │            128 │ convnext_base_stage_0… │
# │ (LayerScale)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_0_bl… │ (None, 56, 56, 128)    │              0 │ convnext_base_stage_0… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_2 (Add)               │ (None, 56, 56, 128)    │              0 │ add_1[0][0],           │
# │                           │                        │                │ convnext_base_stage_0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_downsampli… │ (None, 28, 28, 256)    │        131,584 │ add_2[0][0]            │
# │ (Sequential)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_1_bl… │ (None, 28, 28, 256)    │         12,800 │ convnext_base_downsam… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_1_bl… │ (None, 28, 28, 256)    │            512 │ convnext_base_stage_1… │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_1_bl… │ (None, 28, 28, 1024)   │        263,168 │ convnext_base_stage_1… │
# │ (Dense)                   │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_1_bl… │ (None, 28, 28, 1024)   │              0 │ convnext_base_stage_1… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_1_bl… │ (None, 28, 28, 256)    │        262,400 │ convnext_base_stage_1… │
# │ (Dense)                   │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_1_bl… │ (None, 28, 28, 256)    │            256 │ convnext_base_stage_1… │
# │ (LayerScale)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_1_bl… │ (None, 28, 28, 256)    │              0 │ convnext_base_stage_1… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_3 (Add)               │ (None, 28, 28, 256)    │              0 │ convnext_base_downsam… │
# │                           │                        │                │ convnext_base_stage_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_1_bl… │ (None, 28, 28, 256)    │         12,800 │ add_3[0][0]            │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_1_bl… │ (None, 28, 28, 256)    │            512 │ convnext_base_stage_1… │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_1_bl… │ (None, 28, 28, 1024)   │        263,168 │ convnext_base_stage_1… │
# │ (Dense)                   │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_1_bl… │ (None, 28, 28, 1024)   │              0 │ convnext_base_stage_1… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_1_bl… │ (None, 28, 28, 256)    │        262,400 │ convnext_base_stage_1… │
# │ (Dense)                   │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_1_bl… │ (None, 28, 28, 256)    │            256 │ convnext_base_stage_1… │
# │ (LayerScale)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_1_bl… │ (None, 28, 28, 256)    │              0 │ convnext_base_stage_1… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_4 (Add)               │ (None, 28, 28, 256)    │              0 │ add_3[0][0],           │
# │                           │                        │                │ convnext_base_stage_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_1_bl… │ (None, 28, 28, 256)    │         12,800 │ add_4[0][0]            │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_1_bl… │ (None, 28, 28, 256)    │            512 │ convnext_base_stage_1… │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_1_bl… │ (None, 28, 28, 1024)   │        263,168 │ convnext_base_stage_1… │
# │ (Dense)                   │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_1_bl… │ (None, 28, 28, 1024)   │              0 │ convnext_base_stage_1… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_1_bl… │ (None, 28, 28, 256)    │        262,400 │ convnext_base_stage_1… │
# │ (Dense)                   │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_1_bl… │ (None, 28, 28, 256)    │            256 │ convnext_base_stage_1… │
# │ (LayerScale)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_1_bl… │ (None, 28, 28, 256)    │              0 │ convnext_base_stage_1… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_5 (Add)               │ (None, 28, 28, 256)    │              0 │ add_4[0][0],           │
# │                           │                        │                │ convnext_base_stage_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_downsampli… │ (None, 14, 14, 512)    │        525,312 │ add_5[0][0]            │
# │ (Sequential)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_2_bl… │ (None, 14, 14, 512)    │         25,600 │ convnext_base_downsam… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_2_bl… │ (None, 14, 14, 512)    │          1,024 │ convnext_base_stage_2… │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_2_bl… │ (None, 14, 14, 2048)   │      1,050,624 │ convnext_base_stage_2… │
# │ (Dense)                   │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_2_bl… │ (None, 14, 14, 2048)   │              0 │ convnext_base_stage_2… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_2_bl… │ (None, 14, 14, 512)    │      1,049,088 │ convnext_base_stage_2… │
# │ (Dense)                   │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_2_bl… │ (None, 14, 14, 512)    │            512 │ convnext_base_stage_2… │
# │ (LayerScale)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_2_bl… │ (None, 14, 14, 512)    │              0 │ convnext_base_stage_2… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_6 (Add)               │ (None, 14, 14, 512)    │              0 │ convnext_base_downsam… │
# │                           │                        │                │ convnext_base_stage_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_2_bl… │ (None, 14, 14, 512)    │         25,600 │ add_6[0][0]            │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_2_bl… │ (None, 14, 14, 512)    │          1,024 │ convnext_base_stage_2… │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_2_bl… │ (None, 14, 14, 2048)   │      1,050,624 │ convnext_base_stage_2… │
# │ (Dense)                   │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_2_bl… │ (None, 14, 14, 2048)   │              0 │ convnext_base_stage_2… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_2_bl… │ (None, 14, 14, 512)    │      1,049,088 │ convnext_base_stage_2… │
# │ (Dense)                   │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_2_bl… │ (None, 14, 14, 512)    │            512 │ convnext_base_stage_2… │
# │ (LayerScale)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_2_bl… │ (None, 14, 14, 512)    │              0 │ convnext_base_stage_2… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_7 (Add)               │ (None, 14, 14, 512)    │              0 │ add_6[0][0],           │
# │                           │                        │                │ convnext_base_stage_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_2_bl… │ (None, 14, 14, 512)    │         25,600 │ add_7[0][0]            │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_2_bl… │ (None, 14, 14, 512)    │          1,024 │ convnext_base_stage_2… │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_2_bl… │ (None, 14, 14, 2048)   │      1,050,624 │ convnext_base_stage_2… │
# │ (Dense)                   │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_2_bl… │ (None, 14, 14, 2048)   │              0 │ convnext_base_stage_2… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_2_bl… │ (None, 14, 14, 512)    │      1,049,088 │ convnext_base_stage_2… │
# │ (Dense)                   │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_2_bl… │ (None, 14, 14, 512)    │            512 │ convnext_base_stage_2… │
# │ (LayerScale)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_2_bl… │ (None, 14, 14, 512)    │              0 │ convnext_base_stage_2… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_8 (Add)               │ (None, 14, 14, 512)    │              0 │ add_7[0][0],           │
# │                           │                        │                │ convnext_base_stage_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_2_bl… │ (None, 14, 14, 512)    │         25,600 │ add_8[0][0]            │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_2_bl… │ (None, 14, 14, 512)    │          1,024 │ convnext_base_stage_2… │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_2_bl… │ (None, 14, 14, 2048)   │      1,050,624 │ convnext_base_stage_2… │
# │ (Dense)                   │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_2_bl… │ (None, 14, 14, 2048)   │              0 │ convnext_base_stage_2… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_2_bl… │ (None, 14, 14, 512)    │      1,049,088 │ convnext_base_stage_2… │
# │ (Dense)                   │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_2_bl… │ (None, 14, 14, 512)    │            512 │ convnext_base_stage_2… │
# │ (LayerScale)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_2_bl… │ (None, 14, 14, 512)    │              0 │ convnext_base_stage_2… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_9 (Add)               │ (None, 14, 14, 512)    │              0 │ add_8[0][0],           │
# │                           │                        │                │ convnext_base_stage_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_2_bl… │ (None, 14, 14, 512)    │         25,600 │ add_9[0][0]            │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_2_bl… │ (None, 14, 14, 512)    │          1,024 │ convnext_base_stage_2… │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_2_bl… │ (None, 14, 14, 2048)   │      1,050,624 │ convnext_base_stage_2… │
# │ (Dense)                   │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_2_bl… │ (None, 14, 14, 2048)   │              0 │ convnext_base_stage_2… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_2_bl… │ (None, 14, 14, 512)    │      1,049,088 │ convnext_base_stage_2… │
# │ (Dense)                   │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_2_bl… │ (None, 14, 14, 512)    │            512 │ convnext_base_stage_2… │
# │ (LayerScale)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_2_bl… │ (None, 14, 14, 512)    │              0 │ convnext_base_stage_2… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_10 (Add)              │ (None, 14, 14, 512)    │              0 │ add_9[0][0],           │
# │                           │                        │                │ convnext_base_stage_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_2_bl… │ (None, 14, 14, 512)    │         25,600 │ add_10[0][0]           │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_2_bl… │ (None, 14, 14, 512)    │          1,024 │ convnext_base_stage_2… │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_2_bl… │ (None, 14, 14, 2048)   │      1,050,624 │ convnext_base_stage_2… │
# │ (Dense)                   │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_2_bl… │ (None, 14, 14, 2048)   │              0 │ convnext_base_stage_2… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_2_bl… │ (None, 14, 14, 512)    │      1,049,088 │ convnext_base_stage_2… │
# │ (Dense)                   │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_2_bl… │ (None, 14, 14, 512)    │            512 │ convnext_base_stage_2… │
# │ (LayerScale)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_2_bl… │ (None, 14, 14, 512)    │              0 │ convnext_base_stage_2… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_11 (Add)              │ (None, 14, 14, 512)    │              0 │ add_10[0][0],          │
# │                           │                        │                │ convnext_base_stage_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_2_bl… │ (None, 14, 14, 512)    │         25,600 │ add_11[0][0]           │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_2_bl… │ (None, 14, 14, 512)    │          1,024 │ convnext_base_stage_2… │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_2_bl… │ (None, 14, 14, 2048)   │      1,050,624 │ convnext_base_stage_2… │
# │ (Dense)                   │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_2_bl… │ (None, 14, 14, 2048)   │              0 │ convnext_base_stage_2… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_2_bl… │ (None, 14, 14, 512)    │      1,049,088 │ convnext_base_stage_2… │
# │ (Dense)                   │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_2_bl… │ (None, 14, 14, 512)    │            512 │ convnext_base_stage_2… │
# │ (LayerScale)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_2_bl… │ (None, 14, 14, 512)    │              0 │ convnext_base_stage_2… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_12 (Add)              │ (None, 14, 14, 512)    │              0 │ add_11[0][0],          │
# │                           │                        │                │ convnext_base_stage_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_2_bl… │ (None, 14, 14, 512)    │         25,600 │ add_12[0][0]           │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_2_bl… │ (None, 14, 14, 512)    │          1,024 │ convnext_base_stage_2… │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_2_bl… │ (None, 14, 14, 2048)   │      1,050,624 │ convnext_base_stage_2… │
# │ (Dense)                   │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_2_bl… │ (None, 14, 14, 2048)   │              0 │ convnext_base_stage_2… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_2_bl… │ (None, 14, 14, 512)    │      1,049,088 │ convnext_base_stage_2… │
# │ (Dense)                   │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_2_bl… │ (None, 14, 14, 512)    │            512 │ convnext_base_stage_2… │
# │ (LayerScale)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_2_bl… │ (None, 14, 14, 512)    │              0 │ convnext_base_stage_2… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_13 (Add)              │ (None, 14, 14, 512)    │              0 │ add_12[0][0],          │
# │                           │                        │                │ convnext_base_stage_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_2_bl… │ (None, 14, 14, 512)    │         25,600 │ add_13[0][0]           │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_2_bl… │ (None, 14, 14, 512)    │          1,024 │ convnext_base_stage_2… │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_2_bl… │ (None, 14, 14, 2048)   │      1,050,624 │ convnext_base_stage_2… │
# │ (Dense)                   │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_2_bl… │ (None, 14, 14, 2048)   │              0 │ convnext_base_stage_2… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_2_bl… │ (None, 14, 14, 512)    │      1,049,088 │ convnext_base_stage_2… │
# │ (Dense)                   │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_2_bl… │ (None, 14, 14, 512)    │            512 │ convnext_base_stage_2… │
# │ (LayerScale)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_2_bl… │ (None, 14, 14, 512)    │              0 │ convnext_base_stage_2… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_14 (Add)              │ (None, 14, 14, 512)    │              0 │ add_13[0][0],          │
# │                           │                        │                │ convnext_base_stage_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_2_bl… │ (None, 14, 14, 512)    │         25,600 │ add_14[0][0]           │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_2_bl… │ (None, 14, 14, 512)    │          1,024 │ convnext_base_stage_2… │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_2_bl… │ (None, 14, 14, 2048)   │      1,050,624 │ convnext_base_stage_2… │
# │ (Dense)                   │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_2_bl… │ (None, 14, 14, 2048)   │              0 │ convnext_base_stage_2… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_2_bl… │ (None, 14, 14, 512)    │      1,049,088 │ convnext_base_stage_2… │
# │ (Dense)                   │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_2_bl… │ (None, 14, 14, 512)    │            512 │ convnext_base_stage_2… │
# │ (LayerScale)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_2_bl… │ (None, 14, 14, 512)    │              0 │ convnext_base_stage_2… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_15 (Add)              │ (None, 14, 14, 512)    │              0 │ add_14[0][0],          │
# │                           │                        │                │ convnext_base_stage_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_2_bl… │ (None, 14, 14, 512)    │         25,600 │ add_15[0][0]           │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_2_bl… │ (None, 14, 14, 512)    │          1,024 │ convnext_base_stage_2… │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_2_bl… │ (None, 14, 14, 2048)   │      1,050,624 │ convnext_base_stage_2… │
# │ (Dense)                   │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_2_bl… │ (None, 14, 14, 2048)   │              0 │ convnext_base_stage_2… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_2_bl… │ (None, 14, 14, 512)    │      1,049,088 │ convnext_base_stage_2… │
# │ (Dense)                   │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_2_bl… │ (None, 14, 14, 512)    │            512 │ convnext_base_stage_2… │
# │ (LayerScale)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_2_bl… │ (None, 14, 14, 512)    │              0 │ convnext_base_stage_2… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_16 (Add)              │ (None, 14, 14, 512)    │              0 │ add_15[0][0],          │
# │                           │                        │                │ convnext_base_stage_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_2_bl… │ (None, 14, 14, 512)    │         25,600 │ add_16[0][0]           │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_2_bl… │ (None, 14, 14, 512)    │          1,024 │ convnext_base_stage_2… │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_2_bl… │ (None, 14, 14, 2048)   │      1,050,624 │ convnext_base_stage_2… │
# │ (Dense)                   │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_2_bl… │ (None, 14, 14, 2048)   │              0 │ convnext_base_stage_2… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_2_bl… │ (None, 14, 14, 512)    │      1,049,088 │ convnext_base_stage_2… │
# │ (Dense)                   │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_2_bl… │ (None, 14, 14, 512)    │            512 │ convnext_base_stage_2… │
# │ (LayerScale)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_2_bl… │ (None, 14, 14, 512)    │              0 │ convnext_base_stage_2… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_17 (Add)              │ (None, 14, 14, 512)    │              0 │ add_16[0][0],          │
# │                           │                        │                │ convnext_base_stage_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_2_bl… │ (None, 14, 14, 512)    │         25,600 │ add_17[0][0]           │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_2_bl… │ (None, 14, 14, 512)    │          1,024 │ convnext_base_stage_2… │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_2_bl… │ (None, 14, 14, 2048)   │      1,050,624 │ convnext_base_stage_2… │
# │ (Dense)                   │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_2_bl… │ (None, 14, 14, 2048)   │              0 │ convnext_base_stage_2… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_2_bl… │ (None, 14, 14, 512)    │      1,049,088 │ convnext_base_stage_2… │
# │ (Dense)                   │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_2_bl… │ (None, 14, 14, 512)    │            512 │ convnext_base_stage_2… │
# │ (LayerScale)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_2_bl… │ (None, 14, 14, 512)    │              0 │ convnext_base_stage_2… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_18 (Add)              │ (None, 14, 14, 512)    │              0 │ add_17[0][0],          │
# │                           │                        │                │ convnext_base_stage_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_2_bl… │ (None, 14, 14, 512)    │         25,600 │ add_18[0][0]           │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_2_bl… │ (None, 14, 14, 512)    │          1,024 │ convnext_base_stage_2… │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_2_bl… │ (None, 14, 14, 2048)   │      1,050,624 │ convnext_base_stage_2… │
# │ (Dense)                   │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_2_bl… │ (None, 14, 14, 2048)   │              0 │ convnext_base_stage_2… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_2_bl… │ (None, 14, 14, 512)    │      1,049,088 │ convnext_base_stage_2… │
# │ (Dense)                   │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_2_bl… │ (None, 14, 14, 512)    │            512 │ convnext_base_stage_2… │
# │ (LayerScale)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_2_bl… │ (None, 14, 14, 512)    │              0 │ convnext_base_stage_2… │
# ...
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_29 (Add)              │ (None, 14, 14, 512)    │              0 │ add_28[0][0],          │
# │                           │                        │                │ convnext_base_stage_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_2_bl… │ (None, 14, 14, 512)    │         25,600 │ add_29[0][0]           │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_2_bl… │ (None, 14, 14, 512)    │          1,024 │ convnext_base_stage_2… │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_2_bl… │ (None, 14, 14, 2048)   │      1,050,624 │ convnext_base_stage_2… │
# │ (Dense)                   │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_2_bl… │ (None, 14, 14, 2048)   │              0 │ convnext_base_stage_2… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_2_bl… │ (None, 14, 14, 512)    │      1,049,088 │ convnext_base_stage_2… │
# │ (Dense)                   │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_2_bl… │ (None, 14, 14, 512)    │            512 │ convnext_base_stage_2… │
# │ (LayerScale)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_2_bl… │ (None, 14, 14, 512)    │              0 │ convnext_base_stage_2… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_30 (Add)              │ (None, 14, 14, 512)    │              0 │ add_29[0][0],          │
# │                           │                        │                │ convnext_base_stage_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_2_bl… │ (None, 14, 14, 512)    │         25,600 │ add_30[0][0]           │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_2_bl… │ (None, 14, 14, 512)    │          1,024 │ convnext_base_stage_2… │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_2_bl… │ (None, 14, 14, 2048)   │      1,050,624 │ convnext_base_stage_2… │
# │ (Dense)                   │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_2_bl… │ (None, 14, 14, 2048)   │              0 │ convnext_base_stage_2… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_2_bl… │ (None, 14, 14, 512)    │      1,049,088 │ convnext_base_stage_2… │
# │ (Dense)                   │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_2_bl… │ (None, 14, 14, 512)    │            512 │ convnext_base_stage_2… │
# │ (LayerScale)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_2_bl… │ (None, 14, 14, 512)    │              0 │ convnext_base_stage_2… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_31 (Add)              │ (None, 14, 14, 512)    │              0 │ add_30[0][0],          │
# │                           │                        │                │ convnext_base_stage_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_2_bl… │ (None, 14, 14, 512)    │         25,600 │ add_31[0][0]           │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_2_bl… │ (None, 14, 14, 512)    │          1,024 │ convnext_base_stage_2… │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_2_bl… │ (None, 14, 14, 2048)   │      1,050,624 │ convnext_base_stage_2… │
# │ (Dense)                   │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_2_bl… │ (None, 14, 14, 2048)   │              0 │ convnext_base_stage_2… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_2_bl… │ (None, 14, 14, 512)    │      1,049,088 │ convnext_base_stage_2… │
# │ (Dense)                   │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_2_bl… │ (None, 14, 14, 512)    │            512 │ convnext_base_stage_2… │
# │ (LayerScale)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_2_bl… │ (None, 14, 14, 512)    │              0 │ convnext_base_stage_2… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_32 (Add)              │ (None, 14, 14, 512)    │              0 │ add_31[0][0],          │
# │                           │                        │                │ convnext_base_stage_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_downsampli… │ (None, 7, 7, 1024)     │      2,099,200 │ add_32[0][0]           │
# │ (Sequential)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_3_bl… │ (None, 7, 7, 1024)     │         51,200 │ convnext_base_downsam… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_3_bl… │ (None, 7, 7, 1024)     │          2,048 │ convnext_base_stage_3… │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_3_bl… │ (None, 7, 7, 4096)     │      4,198,400 │ convnext_base_stage_3… │
# │ (Dense)                   │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_3_bl… │ (None, 7, 7, 4096)     │              0 │ convnext_base_stage_3… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_3_bl… │ (None, 7, 7, 1024)     │      4,195,328 │ convnext_base_stage_3… │
# │ (Dense)                   │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_3_bl… │ (None, 7, 7, 1024)     │          1,024 │ convnext_base_stage_3… │
# │ (LayerScale)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_3_bl… │ (None, 7, 7, 1024)     │              0 │ convnext_base_stage_3… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_33 (Add)              │ (None, 7, 7, 1024)     │              0 │ convnext_base_downsam… │
# │                           │                        │                │ convnext_base_stage_3… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_3_bl… │ (None, 7, 7, 1024)     │         51,200 │ add_33[0][0]           │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_3_bl… │ (None, 7, 7, 1024)     │          2,048 │ convnext_base_stage_3… │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_3_bl… │ (None, 7, 7, 4096)     │      4,198,400 │ convnext_base_stage_3… │
# │ (Dense)                   │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_3_bl… │ (None, 7, 7, 4096)     │              0 │ convnext_base_stage_3… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_3_bl… │ (None, 7, 7, 1024)     │      4,195,328 │ convnext_base_stage_3… │
# │ (Dense)                   │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_3_bl… │ (None, 7, 7, 1024)     │          1,024 │ convnext_base_stage_3… │
# │ (LayerScale)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_3_bl… │ (None, 7, 7, 1024)     │              0 │ convnext_base_stage_3… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_34 (Add)              │ (None, 7, 7, 1024)     │              0 │ add_33[0][0],          │
# │                           │                        │                │ convnext_base_stage_3… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_3_bl… │ (None, 7, 7, 1024)     │         51,200 │ add_34[0][0]           │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_3_bl… │ (None, 7, 7, 1024)     │          2,048 │ convnext_base_stage_3… │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_3_bl… │ (None, 7, 7, 4096)     │      4,198,400 │ convnext_base_stage_3… │
# │ (Dense)                   │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_3_bl… │ (None, 7, 7, 4096)     │              0 │ convnext_base_stage_3… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_3_bl… │ (None, 7, 7, 1024)     │      4,195,328 │ convnext_base_stage_3… │
# │ (Dense)                   │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_3_bl… │ (None, 7, 7, 1024)     │          1,024 │ convnext_base_stage_3… │
# │ (LayerScale)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ convnext_base_stage_3_bl… │ (None, 7, 7, 1024)     │              0 │ convnext_base_stage_3… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_35 (Add)              │ (None, 7, 7, 1024)     │              0 │ add_34[0][0],          │
# │                           │                        │                │ convnext_base_stage_3… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization       │ (None, 7, 7, 1024)     │          2,048 │ add_35[0][0]           │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling2d  │ (None, 1024)           │              0 │ layer_normalization[0… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense (Dense)             │ (None, 512)            │        524,800 │ global_average_poolin… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout (Dropout)         │ (None, 512)            │              0 │ dense[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_1 (Dense)           │ (None, 3)              │          1,539 │ dropout[0][0]          │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 88,092,803 (336.05 MB)
#  Trainable params: 526,339 (2.01 MB)
#  Non-trainable params: 87,566,464 (334.04 MB)

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    loss='categorical_crossentropy',
    metrics=['accuracy', Precision(name='precision'), Recall(name='recall'), f1_score]
)
history = model.fit(
    train_generator,
    validation_data=validation_generator,
    epochs=70,
    steps_per_epoch=train_generator.samples // BATCH_SIZE,
    validation_steps=validation_generator.samples // BATCH_SIZE
)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 228s 31s/step - accuracy: 0.4780 - f1_score: 0.3772 - loss: 1.5539 - precision: 0.4986 - recall: 0.4272 - val_accuracy: 0.7128 - val_f1_score: 0.5546 - val_loss: 0.8859 - val_precision: 0.7128 - val_recall: 0.7128
# Epoch 2/70
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.7109 - f1_score: 0.5767 - loss: 0.9667 - precision: 0.7165 - recall: 0.7109
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/epoch_iterator.py:107: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 484ms/step - accuracy: 0.7109 - f1_score: 0.5767 - loss: 0.9667 - precision: 0.7165 - recall: 0.7109 - val_accuracy: 0.6064 - val_f1_score: 0.5795 - val_loss: 0.9983 - val_precision: 0.6064 - val_recall: 0.6064
# Epoch 3/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 4s/step - accuracy: 0.7256 - f1_score: 0.6059 - loss: 0.7199 - precision: 0.7536 - recall: 0.6980 - val_accuracy: 0.8138 - val_f1_score: 0.6556 - val_loss: 0.4510 - val_precision: 0.8606 - val_recall: 0.7553
# Epoch 4/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 488ms/step - accuracy: 0.8164 - f1_score: 0.6647 - loss: 0.4762 - precision: 0.8502 - recall: 0.7539 - val_accuracy: 0.8511 - val_f1_score: 0.6727 - val_loss: 0.3528 - val_precision: 0.8786 - val_recall: 0.8085
# Epoch 5/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 4s/step - accuracy: 0.8259 - f1_score: 0.6910 - loss: 0.4470 - precision: 0.8464 - recall: 0.7987 - val_accuracy: 0.8883 - val_f1_score: 0.7222 - val_loss: 0.2868 - val_precision: 0.9006 - val_recall: 0.8670
# Epoch 6/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 490ms/step - accuracy: 0.8503 - f1_score: 0.7256 - loss: 0.4125 - precision: 0.8774 - recall: 0.8144 - val_accuracy: 0.9043 - val_f1_score: 0.7309 - val_loss: 0.2551 - val_precision: 0.9270 - val_recall: 0.8777
# Epoch 7/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - accuracy: 0.8759 - f1_score: 0.7424 - loss: 0.3504 - precision: 0.8940 - recall: 0.8417 - val_accuracy: 0.8989 - val_f1_score: 0.7600 - val_loss: 0.2526 - val_precision: 0.9171 - val_recall: 0.8830
# Epoch 8/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 481ms/step - accuracy: 0.8711 - f1_score: 0.7635 - loss: 0.3105 - precision: 0.8898 - recall: 0.8516 - val_accuracy: 0.8936 - val_f1_score: 0.7665 - val_loss: 0.2606 - val_precision: 0.9310 - val_recall: 0.8617
# Epoch 9/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 22s 4s/step - accuracy: 0.8884 - f1_score: 0.7748 - loss: 0.3095 - precision: 0.9097 - recall: 0.8679 - val_accuracy: 0.9096 - val_f1_score: 0.7882 - val_loss: 0.2368 - val_precision: 0.9486 - val_recall: 0.8830
# Epoch 10/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 499ms/step - accuracy: 0.8862 - f1_score: 0.7897 - loss: 0.3204 - precision: 0.8944 - recall: 0.8623 - val_accuracy: 0.9255 - val_f1_score: 0.7920 - val_loss: 0.2127 - val_precision: 0.9438 - val_recall: 0.8936
# Epoch 11/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 22s 4s/step - accuracy: 0.9032 - f1_score: 0.7983 - loss: 0.2791 - precision: 0.9201 - recall: 0.8861 - val_accuracy: 0.9096 - val_f1_score: 0.8075 - val_loss: 0.2297 - val_precision: 0.9239 - val_recall: 0.9043
# Epoch 12/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 502ms/step - accuracy: 0.8982 - f1_score: 0.8088 - loss: 0.2958 - precision: 0.9130 - recall: 0.8802 - val_accuracy: 0.9255 - val_f1_score: 0.8105 - val_loss: 0.2389 - val_precision: 0.9396 - val_recall: 0.9096
# Epoch 13/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - accuracy: 0.9125 - f1_score: 0.8151 - loss: 0.2592 - precision: 0.9244 - recall: 0.8941 - val_accuracy: 0.9149 - val_f1_score: 0.8222 - val_loss: 0.2018 - val_precision: 0.9494 - val_recall: 0.8989
# Epoch 14/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 490ms/step - accuracy: 0.9062 - f1_score: 0.8236 - loss: 0.2807 - precision: 0.9124 - recall: 0.8945 - val_accuracy: 0.9255 - val_f1_score: 0.8250 - val_loss: 0.1961 - val_precision: 0.9348 - val_recall: 0.9149
# Epoch 15/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 3s/step - accuracy: 0.9005 - f1_score: 0.8277 - loss: 0.2649 - precision: 0.9202 - recall: 0.8789 - val_accuracy: 0.9096 - val_f1_score: 0.8332 - val_loss: 0.2153 - val_precision: 0.9126 - val_recall: 0.8883
# Epoch 16/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 485ms/step - accuracy: 0.8984 - f1_score: 0.8343 - loss: 0.2834 - precision: 0.9150 - recall: 0.8828 - val_accuracy: 0.9255 - val_f1_score: 0.8353 - val_loss: 0.2167 - val_precision: 0.9392 - val_recall: 0.9043
# Epoch 17/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 4s/step - accuracy: 0.9047 - f1_score: 0.8375 - loss: 0.2578 - precision: 0.9213 - recall: 0.8937 - val_accuracy: 0.9309 - val_f1_score: 0.8421 - val_loss: 0.2189 - val_precision: 0.9396 - val_recall: 0.9096
# Epoch 18/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 501ms/step - accuracy: 0.8984 - f1_score: 0.8430 - loss: 0.3084 - precision: 0.9265 - recall: 0.8867 - val_accuracy: 0.9202 - val_f1_score: 0.8438 - val_loss: 0.2172 - val_precision: 0.9392 - val_recall: 0.9043
# Epoch 19/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 4s/step - accuracy: 0.9016 - f1_score: 0.8454 - loss: 0.2623 - precision: 0.9188 - recall: 0.8864 - val_accuracy: 0.9309 - val_f1_score: 0.8493 - val_loss: 0.2028 - val_precision: 0.9444 - val_recall: 0.9043
# Epoch 20/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 486ms/step - accuracy: 0.9336 - f1_score: 0.8503 - loss: 0.2151 - precision: 0.9435 - recall: 0.9141 - val_accuracy: 0.9149 - val_f1_score: 0.8510 - val_loss: 0.1958 - val_precision: 0.9497 - val_recall: 0.9043
# Epoch 21/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 4s/step - accuracy: 0.9115 - f1_score: 0.8525 - loss: 0.2384 - precision: 0.9283 - recall: 0.8952 - val_accuracy: 0.9309 - val_f1_score: 0.8560 - val_loss: 0.2058 - val_precision: 0.9500 - val_recall: 0.9096
# Epoch 22/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 487ms/step - accuracy: 0.9141 - f1_score: 0.8566 - loss: 0.2491 - precision: 0.9137 - recall: 0.9102 - val_accuracy: 0.9309 - val_f1_score: 0.8572 - val_loss: 0.1922 - val_precision: 0.9344 - val_recall: 0.9096
# Epoch 23/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 3s/step - accuracy: 0.9155 - f1_score: 0.8587 - loss: 0.2309 - precision: 0.9341 - recall: 0.9001 - val_accuracy: 0.9149 - val_f1_score: 0.8610 - val_loss: 0.2176 - val_precision: 0.9189 - val_recall: 0.9043
# Epoch 24/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 496ms/step - accuracy: 0.9258 - f1_score: 0.8617 - loss: 0.1980 - precision: 0.9289 - recall: 0.9180 - val_accuracy: 0.9149 - val_f1_score: 0.8622 - val_loss: 0.2217 - val_precision: 0.9396 - val_recall: 0.9096
# Epoch 25/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 3s/step - accuracy: 0.9272 - f1_score: 0.8635 - loss: 0.2165 - precision: 0.9383 - recall: 0.9092 - val_accuracy: 0.9415 - val_f1_score: 0.8663 - val_loss: 0.1956 - val_precision: 0.9448 - val_recall: 0.9096
# Epoch 26/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 512ms/step - accuracy: 0.9375 - f1_score: 0.8668 - loss: 0.2226 - precision: 0.9472 - recall: 0.9102 - val_accuracy: 0.9309 - val_f1_score: 0.8673 - val_loss: 0.2214 - val_precision: 0.9553 - val_recall: 0.9096
# Epoch 27/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 3s/step - accuracy: 0.9154 - f1_score: 0.8683 - loss: 0.2103 - precision: 0.9280 - recall: 0.9008 - val_accuracy: 0.9255 - val_f1_score: 0.8704 - val_loss: 0.2366 - val_precision: 0.9251 - val_recall: 0.9202
# Epoch 28/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 501ms/step - accuracy: 0.9180 - f1_score: 0.8708 - loss: 0.2215 - precision: 0.9317 - recall: 0.9062 - val_accuracy: 0.8989 - val_f1_score: 0.8710 - val_loss: 0.2430 - val_precision: 0.9032 - val_recall: 0.8936
# Epoch 29/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 4s/step - accuracy: 0.9342 - f1_score: 0.8720 - loss: 0.2015 - precision: 0.9458 - recall: 0.9125 - val_accuracy: 0.9468 - val_f1_score: 0.8742 - val_loss: 0.1747 - val_precision: 0.9516 - val_recall: 0.9415
# Epoch 30/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 515ms/step - accuracy: 0.9141 - f1_score: 0.8746 - loss: 0.2300 - precision: 0.9320 - recall: 0.9102 - val_accuracy: 0.9309 - val_f1_score: 0.8749 - val_loss: 0.2199 - val_precision: 0.9405 - val_recall: 0.9255
# Epoch 31/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 3s/step - accuracy: 0.9252 - f1_score: 0.8759 - loss: 0.2004 - precision: 0.9393 - recall: 0.9145 - val_accuracy: 0.9255 - val_f1_score: 0.8775 - val_loss: 0.1963 - val_precision: 0.9351 - val_recall: 0.9202
# Epoch 32/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 505ms/step - accuracy: 0.9453 - f1_score: 0.8780 - loss: 0.1783 - precision: 0.9562 - recall: 0.9375 - val_accuracy: 0.9149 - val_f1_score: 0.8782 - val_loss: 0.2018 - val_precision: 0.9337 - val_recall: 0.8989
# Epoch 33/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 3s/step - accuracy: 0.9298 - f1_score: 0.8791 - loss: 0.2010 - precision: 0.9367 - recall: 0.9190 - val_accuracy: 0.9202 - val_f1_score: 0.8805 - val_loss: 0.2100 - val_precision: 0.9235 - val_recall: 0.8989
# Epoch 34/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 515ms/step - accuracy: 0.9336 - f1_score: 0.8809 - loss: 0.2206 - precision: 0.9365 - recall: 0.9219 - val_accuracy: 0.9309 - val_f1_score: 0.8811 - val_loss: 0.1867 - val_precision: 0.9344 - val_recall: 0.9096
# Epoch 35/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - accuracy: 0.9347 - f1_score: 0.8819 - loss: 0.1867 - precision: 0.9444 - recall: 0.9244 - val_accuracy: 0.9255 - val_f1_score: 0.8835 - val_loss: 0.2132 - val_precision: 0.9457 - val_recall: 0.9255
# Epoch 36/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 511ms/step - accuracy: 0.9414 - f1_score: 0.8839 - loss: 0.1556 - precision: 0.9563 - recall: 0.9414 - val_accuracy: 0.9521 - val_f1_score: 0.8843 - val_loss: 0.1819 - val_precision: 0.9565 - val_recall: 0.9362
# Epoch 37/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 3s/step - accuracy: 0.9357 - f1_score: 0.8850 - loss: 0.1831 - precision: 0.9454 - recall: 0.9186 - val_accuracy: 0.9415 - val_f1_score: 0.8863 - val_loss: 0.1879 - val_precision: 0.9558 - val_recall: 0.9202
# Epoch 38/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 499ms/step - accuracy: 0.9297 - f1_score: 0.8866 - loss: 0.2178 - precision: 0.9400 - recall: 0.9180 - val_accuracy: 0.9309 - val_f1_score: 0.8869 - val_loss: 0.2165 - val_precision: 0.9613 - val_recall: 0.9255
# Epoch 39/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - accuracy: 0.9379 - f1_score: 0.8877 - loss: 0.1842 - precision: 0.9495 - recall: 0.9288 - val_accuracy: 0.9362 - val_f1_score: 0.8888 - val_loss: 0.1843 - val_precision: 0.9405 - val_recall: 0.9255
# Epoch 40/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 489ms/step - accuracy: 0.9609 - f1_score: 0.8893 - loss: 0.1546 - precision: 0.9683 - recall: 0.9531 - val_accuracy: 0.9362 - val_f1_score: 0.8895 - val_loss: 0.1813 - val_precision: 0.9514 - val_recall: 0.9362
# Epoch 41/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 3s/step - accuracy: 0.9398 - f1_score: 0.8901 - loss: 0.1814 - precision: 0.9473 - recall: 0.9236 - val_accuracy: 0.9362 - val_f1_score: 0.8914 - val_loss: 0.1997 - val_precision: 0.9459 - val_recall: 0.9309
# Epoch 42/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 500ms/step - accuracy: 0.9492 - f1_score: 0.8917 - loss: 0.1422 - precision: 0.9528 - recall: 0.9453 - val_accuracy: 0.9362 - val_f1_score: 0.8919 - val_loss: 0.1973 - val_precision: 0.9457 - val_recall: 0.9255
# Epoch 43/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 3s/step - accuracy: 0.9422 - f1_score: 0.8926 - loss: 0.1632 - precision: 0.9503 - recall: 0.9357 - val_accuracy: 0.9415 - val_f1_score: 0.8937 - val_loss: 0.1770 - val_precision: 0.9405 - val_recall: 0.9255
# Epoch 44/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 494ms/step - accuracy: 0.9531 - f1_score: 0.8940 - loss: 0.1628 - precision: 0.9602 - recall: 0.9414 - val_accuracy: 0.9202 - val_f1_score: 0.8942 - val_loss: 0.1899 - val_precision: 0.9402 - val_recall: 0.9202
# Epoch 45/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - accuracy: 0.9414 - f1_score: 0.8948 - loss: 0.1598 - precision: 0.9503 - recall: 0.9334 - val_accuracy: 0.9362 - val_f1_score: 0.8959 - val_loss: 0.1581 - val_precision: 0.9412 - val_recall: 0.9362
# Epoch 46/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 489ms/step - accuracy: 0.9141 - f1_score: 0.8960 - loss: 0.1948 - precision: 0.9240 - recall: 0.9023 - val_accuracy: 0.9202 - val_f1_score: 0.8961 - val_loss: 0.1921 - val_precision: 0.9348 - val_recall: 0.9149
# Epoch 47/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 3s/step - accuracy: 0.9354 - f1_score: 0.8966 - loss: 0.1649 - precision: 0.9475 - recall: 0.9283 - val_accuracy: 0.9255 - val_f1_score: 0.8976 - val_loss: 0.2138 - val_precision: 0.9402 - val_recall: 0.9202
# Epoch 48/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 484ms/step - accuracy: 0.9258 - f1_score: 0.8977 - loss: 0.1855 - precision: 0.9368 - recall: 0.9258 - val_accuracy: 0.9255 - val_f1_score: 0.8978 - val_loss: 0.1905 - val_precision: 0.9344 - val_recall: 0.9096
# Epoch 49/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 4s/step - accuracy: 0.9452 - f1_score: 0.8983 - loss: 0.1635 - precision: 0.9537 - recall: 0.9313 - val_accuracy: 0.9149 - val_f1_score: 0.8991 - val_loss: 0.2492 - val_precision: 0.9243 - val_recall: 0.9096
# Epoch 50/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 504ms/step - accuracy: 0.9375 - f1_score: 0.8993 - loss: 0.1871 - precision: 0.9412 - recall: 0.9375 - val_accuracy: 0.9149 - val_f1_score: 0.8993 - val_loss: 0.2429 - val_precision: 0.9149 - val_recall: 0.9149
# Epoch 51/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 4s/step - accuracy: 0.9518 - f1_score: 0.8999 - loss: 0.1447 - precision: 0.9579 - recall: 0.9459 - val_accuracy: 0.9309 - val_f1_score: 0.9006 - val_loss: 0.1984 - val_precision: 0.9351 - val_recall: 0.9202
# Epoch 52/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 490ms/step - accuracy: 0.9336 - f1_score: 0.9008 - loss: 0.1814 - precision: 0.9370 - recall: 0.9297 - val_accuracy: 0.9309 - val_f1_score: 0.9009 - val_loss: 0.2194 - val_precision: 0.9293 - val_recall: 0.9096
# Epoch 53/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 4s/step - accuracy: 0.9455 - f1_score: 0.9013 - loss: 0.1572 - precision: 0.9531 - recall: 0.9364 - val_accuracy: 0.9415 - val_f1_score: 0.9021 - val_loss: 0.1703 - val_precision: 0.9505 - val_recall: 0.9202
# Epoch 54/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 488ms/step - accuracy: 0.9492 - f1_score: 0.9023 - loss: 0.1392 - precision: 0.9528 - recall: 0.9453 - val_accuracy: 0.9202 - val_f1_score: 0.9024 - val_loss: 0.1892 - val_precision: 0.9293 - val_recall: 0.9096
# Epoch 55/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - accuracy: 0.9499 - f1_score: 0.9029 - loss: 0.1496 - precision: 0.9568 - recall: 0.9407 - val_accuracy: 0.9096 - val_f1_score: 0.9036 - val_loss: 0.2039 - val_precision: 0.9144 - val_recall: 0.9096
# Epoch 56/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 479ms/step - accuracy: 0.9531 - f1_score: 0.9038 - loss: 0.1357 - precision: 0.9600 - recall: 0.9375 - val_accuracy: 0.9255 - val_f1_score: 0.9039 - val_loss: 0.2068 - val_precision: 0.9503 - val_recall: 0.9149
# Epoch 57/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - accuracy: 0.9538 - f1_score: 0.9044 - loss: 0.1411 - precision: 0.9583 - recall: 0.9430 - val_accuracy: 0.9096 - val_f1_score: 0.9050 - val_loss: 0.2386 - val_precision: 0.9239 - val_recall: 0.9043
# Epoch 58/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 476ms/step - accuracy: 0.9258 - f1_score: 0.9051 - loss: 0.1961 - precision: 0.9328 - recall: 0.9219 - val_accuracy: 0.9096 - val_f1_score: 0.9051 - val_loss: 0.2240 - val_precision: 0.9231 - val_recall: 0.8936
# Epoch 59/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 3s/step - accuracy: 0.9615 - f1_score: 0.9056 - loss: 0.1460 - precision: 0.9686 - recall: 0.9487 - val_accuracy: 0.9255 - val_f1_score: 0.9063 - val_loss: 0.1989 - val_precision: 0.9348 - val_recall: 0.9149
# Epoch 60/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 487ms/step - accuracy: 0.9766 - f1_score: 0.9066 - loss: 0.0785 - precision: 0.9803 - recall: 0.9727 - val_accuracy: 0.9309 - val_f1_score: 0.9067 - val_loss: 0.1827 - val_precision: 0.9457 - val_recall: 0.9255
# Epoch 61/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - accuracy: 0.9510 - f1_score: 0.9071 - loss: 0.1519 - precision: 0.9600 - recall: 0.9442 - val_accuracy: 0.9309 - val_f1_score: 0.9078 - val_loss: 0.2290 - val_precision: 0.9454 - val_recall: 0.9202
# Epoch 62/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 486ms/step - accuracy: 0.9609 - f1_score: 0.9080 - loss: 0.1283 - precision: 0.9606 - recall: 0.9531 - val_accuracy: 0.9309 - val_f1_score: 0.9081 - val_loss: 0.1960 - val_precision: 0.9358 - val_recall: 0.9309
# Epoch 63/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 3s/step - accuracy: 0.9564 - f1_score: 0.9085 - loss: 0.1304 - precision: 0.9615 - recall: 0.9542 - val_accuracy: 0.9043 - val_f1_score: 0.9091 - val_loss: 0.2579 - val_precision: 0.9037 - val_recall: 0.8989
# Epoch 64/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 484ms/step - accuracy: 0.9375 - f1_score: 0.9092 - loss: 0.1449 - precision: 0.9478 - recall: 0.9219 - val_accuracy: 0.9202 - val_f1_score: 0.9092 - val_loss: 0.2265 - val_precision: 0.9251 - val_recall: 0.9202
# Epoch 65/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 4s/step - accuracy: 0.9571 - f1_score: 0.9096 - loss: 0.1236 - precision: 0.9602 - recall: 0.9525 - val_accuracy: 0.9468 - val_f1_score: 0.9103 - val_loss: 0.1777 - val_precision: 0.9516 - val_recall: 0.9415
# Epoch 66/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 489ms/step - accuracy: 0.9180 - f1_score: 0.9104 - loss: 0.1902 - precision: 0.9249 - recall: 0.9141 - val_accuracy: 0.9149 - val_f1_score: 0.9104 - val_loss: 0.2200 - val_precision: 0.9185 - val_recall: 0.8989
# Epoch 67/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 4s/step - accuracy: 0.9588 - f1_score: 0.9107 - loss: 0.1418 - precision: 0.9633 - recall: 0.9498 - val_accuracy: 0.9149 - val_f1_score: 0.9114 - val_loss: 0.2177 - val_precision: 0.9341 - val_recall: 0.9043
# Epoch 68/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 481ms/step - accuracy: 0.9492 - f1_score: 0.9115 - loss: 0.1420 - precision: 0.9528 - recall: 0.9453 - val_accuracy: 0.9362 - val_f1_score: 0.9116 - val_loss: 0.1954 - val_precision: 0.9511 - val_recall: 0.9309
# Epoch 69/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 3s/step - accuracy: 0.9642 - f1_score: 0.9120 - loss: 0.1234 - precision: 0.9711 - recall: 0.9577 - val_accuracy: 0.9149 - val_f1_score: 0.9126 - val_loss: 0.2326 - val_precision: 0.9239 - val_recall: 0.9043
# Epoch 70/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 498ms/step - accuracy: 0.9453 - f1_score: 0.9127 - loss: 0.1326 - precision: 0.9524 - recall: 0.9375 - val_accuracy: 0.9255 - val_f1_score: 0.9128 - val_loss: 0.2124 - val_precision: 0.9351 - val_recall: 0.9202

# %%
# Evaluate the model and unpack the returned values appropriately
test_loss, test_accuracy, test_precision, test_recall, test_f1_score = model.evaluate(validation_generator)

# Print the test accuracy
print(f"Test Accuracy: {test_accuracy * 100:.2f}%")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - accuracy: 0.9309 - f1_score: 0.9128 - loss: 0.2221 - precision: 0.9454 - recall: 0.9202
# Test Accuracy: 93.09%

# %%
# Unfreeze the base model for fine-tuning
base_model.trainable = True

# Use a lower learning rate for fine-tuning
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-5),
    loss='categorical_crossentropy',
    metrics=['accuracy', Precision(name='precision'), Recall(name='recall'), f1_score]
)

# Fine-tune the model
fine_tune_history = model.fit(
    train_generator,
    validation_data=validation_generator,
    epochs=70,  # Add more epochs for fine-tuning
    steps_per_epoch=train_generator.samples // BATCH_SIZE,
    validation_steps=validation_generator.samples // BATCH_SIZE
)
# Out:
# Epoch 1/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 149s 5s/step - accuracy: 0.9640 - f1_score: 0.9133 - loss: 0.1130 - precision: 0.9686 - recall: 0.9574 - val_accuracy: 0.9309 - val_f1_score: 0.9139 - val_loss: 0.2260 - val_precision: 0.9355 - val_recall: 0.9255
# Epoch 2/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 60s 498ms/step - accuracy: 0.9102 - f1_score: 0.9138 - loss: 0.2072 - precision: 0.9085 - recall: 0.8922 - val_accuracy: 0.9362 - val_f1_score: 0.9139 - val_loss: 0.1847 - val_precision: 0.9459 - val_recall: 0.9309
# Epoch 3/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 22s 4s/step - accuracy: 0.9636 - f1_score: 0.9143 - loss: 0.1160 - precision: 0.9646 - recall: 0.9554 - val_accuracy: 0.9202 - val_f1_score: 0.9148 - val_loss: 0.2446 - val_precision: 0.9202 - val_recall: 0.9202
# Epoch 4/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 4s 498ms/step - accuracy: 0.9688 - f1_score: 0.9149 - loss: 0.0932 - precision: 0.9688 - recall: 0.9688 - val_accuracy: 0.9309 - val_f1_score: 0.9150 - val_loss: 0.2034 - val_precision: 0.9301 - val_recall: 0.9202
# Epoch 5/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 22s 3s/step - accuracy: 0.9634 - f1_score: 0.9153 - loss: 0.1162 - precision: 0.9673 - recall: 0.9597 - val_accuracy: 0.9309 - val_f1_score: 0.9159 - val_loss: 0.2036 - val_precision: 0.9457 - val_recall: 0.9255
# Epoch 6/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 4s 486ms/step - accuracy: 0.9805 - f1_score: 0.9161 - loss: 0.0965 - precision: 0.9803 - recall: 0.9727 - val_accuracy: 0.9149 - val_f1_score: 0.9161 - val_loss: 0.2143 - val_precision: 0.9144 - val_recall: 0.9096
# Epoch 7/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 22s 4s/step - accuracy: 0.9626 - f1_score: 0.9164 - loss: 0.0987 - precision: 0.9671 - recall: 0.9572 - val_accuracy: 0.9309 - val_f1_score: 0.9170 - val_loss: 0.1955 - val_precision: 0.9355 - val_recall: 0.9255
# Epoch 8/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 4s 490ms/step - accuracy: 0.9883 - f1_score: 0.9172 - loss: 0.0649 - precision: 0.9883 - recall: 0.9883 - val_accuracy: 0.9149 - val_f1_score: 0.9172 - val_loss: 0.2251 - val_precision: 0.9149 - val_recall: 0.9149
# Epoch 9/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 22s 3s/step - accuracy: 0.9712 - f1_score: 0.9176 - loss: 0.0884 - precision: 0.9711 - recall: 0.9689 - val_accuracy: 0.9521 - val_f1_score: 0.9183 - val_loss: 0.1803 - val_precision: 0.9521 - val_recall: 0.9521
# Epoch 10/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 4s 493ms/step - accuracy: 0.9805 - f1_score: 0.9185 - loss: 0.0692 - precision: 0.9804 - recall: 0.9766 - val_accuracy: 0.9362 - val_f1_score: 0.9185 - val_loss: 0.2350 - val_precision: 0.9358 - val_recall: 0.9309
# Epoch 11/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 3s/step - accuracy: 0.9799 - f1_score: 0.9189 - loss: 0.0785 - precision: 0.9844 - recall: 0.9778 - val_accuracy: 0.9521 - val_f1_score: 0.9196 - val_loss: 0.1876 - val_precision: 0.9624 - val_recall: 0.9521
# Epoch 12/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 482ms/step - accuracy: 0.9766 - f1_score: 0.9198 - loss: 0.0880 - precision: 0.9802 - recall: 0.9688 - val_accuracy: 0.9202 - val_f1_score: 0.9198 - val_loss: 0.2347 - val_precision: 0.9202 - val_recall: 0.9202
# Epoch 13/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 22s 4s/step - accuracy: 0.9793 - f1_score: 0.9202 - loss: 0.0700 - precision: 0.9815 - recall: 0.9779 - val_accuracy: 0.9309 - val_f1_score: 0.9208 - val_loss: 0.2053 - val_precision: 0.9358 - val_recall: 0.9309
# Epoch 14/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 4s 491ms/step - accuracy: 0.9688 - f1_score: 0.9210 - loss: 0.0997 - precision: 0.9764 - recall: 0.9688 - val_accuracy: 0.9415 - val_f1_score: 0.9210 - val_loss: 0.2506 - val_precision: 0.9415 - val_recall: 0.9415
# Epoch 15/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 22s 4s/step - accuracy: 0.9800 - f1_score: 0.9214 - loss: 0.0806 - precision: 0.9805 - recall: 0.9772 - val_accuracy: 0.9521 - val_f1_score: 0.9221 - val_loss: 0.1960 - val_precision: 0.9519 - val_recall: 0.9468
# Epoch 16/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 4s 489ms/step - accuracy: 0.9922 - f1_score: 0.9222 - loss: 0.0472 - precision: 0.9922 - recall: 0.9883 - val_accuracy: 0.9415 - val_f1_score: 0.9223 - val_loss: 0.1692 - val_precision: 0.9516 - val_recall: 0.9415
# Epoch 17/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 22s 4s/step - accuracy: 0.9827 - f1_score: 0.9227 - loss: 0.0681 - precision: 0.9856 - recall: 0.9806 - val_accuracy: 0.9255 - val_f1_score: 0.9233 - val_loss: 0.1979 - val_precision: 0.9255 - val_recall: 0.9255
# Epoch 18/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 4s 500ms/step - accuracy: 0.9844 - f1_score: 0.9235 - loss: 0.0678 - precision: 0.9844 - recall: 0.9844 - val_accuracy: 0.9468 - val_f1_score: 0.9235 - val_loss: 0.1955 - val_precision: 0.9465 - val_recall: 0.9415
# Epoch 19/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 22s 3s/step - accuracy: 0.9767 - f1_score: 0.9238 - loss: 0.0686 - precision: 0.9802 - recall: 0.9736 - val_accuracy: 0.9415 - val_f1_score: 0.9245 - val_loss: 0.1892 - val_precision: 0.9415 - val_recall: 0.9415
# Epoch 20/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 4s 487ms/step - accuracy: 0.9844 - f1_score: 0.9246 - loss: 0.0561 - precision: 0.9881 - recall: 0.9766 - val_accuracy: 0.9309 - val_f1_score: 0.9246 - val_loss: 0.2518 - val_precision: 0.9301 - val_recall: 0.9202
# Epoch 21/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 22s 4s/step - accuracy: 0.9880 - f1_score: 0.9250 - loss: 0.0512 - precision: 0.9888 - recall: 0.9857 - val_accuracy: 0.9202 - val_f1_score: 0.9255 - val_loss: 0.2226 - val_precision: 0.9247 - val_recall: 0.9149
# Epoch 22/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 4s 499ms/step - accuracy: 0.9766 - f1_score: 0.9257 - loss: 0.0507 - precision: 0.9766 - recall: 0.9766 - val_accuracy: 0.9309 - val_f1_score: 0.9257 - val_loss: 0.2489 - val_precision: 0.9358 - val_recall: 0.9309
# Epoch 23/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 22s 4s/step - accuracy: 0.9896 - f1_score: 0.9260 - loss: 0.0503 - precision: 0.9896 - recall: 0.9884 - val_accuracy: 0.9202 - val_f1_score: 0.9266 - val_loss: 0.2199 - val_precision: 0.9251 - val_recall: 0.9202
# Epoch 24/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 4s 491ms/step - accuracy: 0.9805 - f1_score: 0.9268 - loss: 0.0644 - precision: 0.9804 - recall: 0.9766 - val_accuracy: 0.9202 - val_f1_score: 0.9268 - val_loss: 0.2047 - val_precision: 0.9251 - val_recall: 0.9202
# Epoch 25/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 22s 4s/step - accuracy: 0.9890 - f1_score: 0.9271 - loss: 0.0480 - precision: 0.9897 - recall: 0.9883 - val_accuracy: 0.9202 - val_f1_score: 0.9277 - val_loss: 0.2181 - val_precision: 0.9251 - val_recall: 0.9202
# Epoch 26/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 4s 490ms/step - accuracy: 0.9844 - f1_score: 0.9278 - loss: 0.0576 - precision: 0.9844 - recall: 0.9844 - val_accuracy: 0.9415 - val_f1_score: 0.9279 - val_loss: 0.1616 - val_precision: 0.9462 - val_recall: 0.9362
# Epoch 27/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 22s 4s/step - accuracy: 0.9884 - f1_score: 0.9282 - loss: 0.0469 - precision: 0.9884 - recall: 0.9874 - val_accuracy: 0.9202 - val_f1_score: 0.9287 - val_loss: 0.2533 - val_precision: 0.9202 - val_recall: 0.9202
# Epoch 28/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 480ms/step - accuracy: 0.9766 - f1_score: 0.9288 - loss: 0.0656 - precision: 0.9766 - recall: 0.9766 - val_accuracy: 0.9415 - val_f1_score: 0.9288 - val_loss: 0.2086 - val_precision: 0.9415 - val_recall: 0.9415
# Epoch 29/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 22s 3s/step - accuracy: 0.9869 - f1_score: 0.9292 - loss: 0.0476 - precision: 0.9886 - recall: 0.9851 - val_accuracy: 0.9309 - val_f1_score: 0.9297 - val_loss: 0.1965 - val_precision: 0.9358 - val_recall: 0.9309
# Epoch 30/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 4s 501ms/step - accuracy: 0.9922 - f1_score: 0.9299 - loss: 0.0375 - precision: 0.9922 - recall: 0.9922 - val_accuracy: 0.9255 - val_f1_score: 0.9298 - val_loss: 0.2123 - val_precision: 0.9305 - val_recall: 0.9255
# Epoch 31/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 3s/step - accuracy: 0.9912 - f1_score: 0.9302 - loss: 0.0391 - precision: 0.9916 - recall: 0.9906 - val_accuracy: 0.9309 - val_f1_score: 0.9307 - val_loss: 0.2081 - val_precision: 0.9309 - val_recall: 0.9309
# Epoch 32/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 4s 512ms/step - accuracy: 0.9961 - f1_score: 0.9308 - loss: 0.0380 - precision: 0.9961 - recall: 0.9961 - val_accuracy: 0.9255 - val_f1_score: 0.9308 - val_loss: 0.2138 - val_precision: 0.9305 - val_recall: 0.9255
# Epoch 33/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 22s 3s/step - accuracy: 0.9917 - f1_score: 0.9312 - loss: 0.0364 - precision: 0.9917 - recall: 0.9902 - val_accuracy: 0.9415 - val_f1_score: 0.9317 - val_loss: 0.1926 - val_precision: 0.9462 - val_recall: 0.9362
# Epoch 34/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 4s 507ms/step - accuracy: 0.9766 - f1_score: 0.9318 - loss: 0.0646 - precision: 0.9765 - recall: 0.9727 - val_accuracy: 0.9521 - val_f1_score: 0.9318 - val_loss: 0.2059 - val_precision: 0.9521 - val_recall: 0.9521
# Epoch 35/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 22s 4s/step - accuracy: 0.9910 - f1_score: 0.9322 - loss: 0.0327 - precision: 0.9921 - recall: 0.9910 - val_accuracy: 0.9362 - val_f1_score: 0.9326 - val_loss: 0.1515 - val_precision: 0.9358 - val_recall: 0.9309
# Epoch 36/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 4s 508ms/step - accuracy: 0.9883 - f1_score: 0.9327 - loss: 0.0528 - precision: 0.9883 - recall: 0.9883 - val_accuracy: 0.9415 - val_f1_score: 0.9327 - val_loss: 0.2348 - val_precision: 0.9415 - val_recall: 0.9415
# Epoch 37/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 22s 4s/step - accuracy: 0.9881 - f1_score: 0.9330 - loss: 0.0411 - precision: 0.9899 - recall: 0.9866 - val_accuracy: 0.9309 - val_f1_score: 0.9335 - val_loss: 0.2461 - val_precision: 0.9355 - val_recall: 0.9255
# Epoch 38/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 4s 500ms/step - accuracy: 1.0000 - f1_score: 0.9336 - loss: 0.0357 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9362 - val_f1_score: 0.9336 - val_loss: 0.2069 - val_precision: 0.9412 - val_recall: 0.9362
# Epoch 39/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 22s 4s/step - accuracy: 0.9905 - f1_score: 0.9339 - loss: 0.0332 - precision: 0.9914 - recall: 0.9892 - val_accuracy: 0.9362 - val_f1_score: 0.9344 - val_loss: 0.2099 - val_precision: 0.9362 - val_recall: 0.9362
# Epoch 40/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 4s 491ms/step - accuracy: 0.9961 - f1_score: 0.9345 - loss: 0.0257 - precision: 0.9961 - recall: 0.9961 - val_accuracy: 0.9468 - val_f1_score: 0.9346 - val_loss: 0.1450 - val_precision: 0.9516 - val_recall: 0.9415
# Epoch 41/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 23s 4s/step - accuracy: 0.9943 - f1_score: 0.9349 - loss: 0.0287 - precision: 0.9946 - recall: 0.9943 - val_accuracy: 0.9309 - val_f1_score: 0.9354 - val_loss: 0.2209 - val_precision: 0.9358 - val_recall: 0.9309
# Epoch 42/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 485ms/step - accuracy: 0.9880 - f1_score: 0.9354 - loss: 0.0276 - precision: 0.9880 - recall: 0.9820 - val_accuracy: 0.9255 - val_f1_score: 0.9354 - val_loss: 0.2252 - val_precision: 0.9305 - val_recall: 0.9255
# Epoch 43/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 3s/step - accuracy: 0.9935 - f1_score: 0.9357 - loss: 0.0297 - precision: 0.9942 - recall: 0.9935 - val_accuracy: 0.9149 - val_f1_score: 0.9361 - val_loss: 0.2764 - val_precision: 0.9198 - val_recall: 0.9149
# Epoch 44/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 4s 488ms/step - accuracy: 0.9961 - f1_score: 0.9362 - loss: 0.0317 - precision: 0.9961 - recall: 0.9961 - val_accuracy: 0.9362 - val_f1_score: 0.9362 - val_loss: 0.1889 - val_precision: 0.9412 - val_recall: 0.9362
# Epoch 45/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 22s 4s/step - accuracy: 0.9959 - f1_score: 0.9365 - loss: 0.0250 - precision: 0.9959 - recall: 0.9952 - val_accuracy: 0.9202 - val_f1_score: 0.9369 - val_loss: 0.2196 - val_precision: 0.9194 - val_recall: 0.9096
# Epoch 46/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 4s 512ms/step - accuracy: 0.9805 - f1_score: 0.9370 - loss: 0.0447 - precision: 0.9804 - recall: 0.9766 - val_accuracy: 0.9202 - val_f1_score: 0.9370 - val_loss: 0.2276 - val_precision: 0.9202 - val_recall: 0.9202
# Epoch 47/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 22s 4s/step - accuracy: 0.9973 - f1_score: 0.9372 - loss: 0.0207 - precision: 0.9973 - recall: 0.9958 - val_accuracy: 0.9255 - val_f1_score: 0.9376 - val_loss: 0.2418 - val_precision: 0.9305 - val_recall: 0.9255
# Epoch 48/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 478ms/step - accuracy: 1.0000 - f1_score: 0.9378 - loss: 0.0166 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9415 - val_f1_score: 0.9378 - val_loss: 0.2404 - val_precision: 0.9412 - val_recall: 0.9362
# Epoch 49/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 23s 4s/step - accuracy: 0.9977 - f1_score: 0.9381 - loss: 0.0205 - precision: 0.9977 - recall: 0.9977 - val_accuracy: 0.9309 - val_f1_score: 0.9385 - val_loss: 0.1847 - val_precision: 0.9358 - val_recall: 0.9309
# Epoch 50/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 490ms/step - accuracy: 0.9940 - f1_score: 0.9386 - loss: 0.0148 - precision: 0.9940 - recall: 0.9940 - val_accuracy: 0.9362 - val_f1_score: 0.9386 - val_loss: 0.1928 - val_precision: 0.9412 - val_recall: 0.9362
# Epoch 51/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 23s 4s/step - accuracy: 0.9938 - f1_score: 0.9389 - loss: 0.0228 - precision: 0.9938 - recall: 0.9936 - val_accuracy: 0.9362 - val_f1_score: 0.9393 - val_loss: 0.1728 - val_precision: 0.9412 - val_recall: 0.9362
# Epoch 52/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 493ms/step - accuracy: 0.9940 - f1_score: 0.9393 - loss: 0.0298 - precision: 0.9940 - recall: 0.9940 - val_accuracy: 0.9468 - val_f1_score: 0.9394 - val_loss: 0.2358 - val_precision: 0.9519 - val_recall: 0.9468
# Epoch 53/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 22s 4s/step - accuracy: 0.9966 - f1_score: 0.9396 - loss: 0.0216 - precision: 0.9966 - recall: 0.9957 - val_accuracy: 0.9255 - val_f1_score: 0.9400 - val_loss: 0.2175 - val_precision: 0.9305 - val_recall: 0.9255
# Epoch 54/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 4s 490ms/step - accuracy: 0.9922 - f1_score: 0.9401 - loss: 0.0246 - precision: 0.9922 - recall: 0.9922 - val_accuracy: 0.9362 - val_f1_score: 0.9401 - val_loss: 0.2638 - val_precision: 0.9412 - val_recall: 0.9362
# Epoch 55/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 3s/step - accuracy: 0.9957 - f1_score: 0.9404 - loss: 0.0187 - precision: 0.9969 - recall: 0.9955 - val_accuracy: 0.9362 - val_f1_score: 0.9407 - val_loss: 0.2089 - val_precision: 0.9362 - val_recall: 0.9362
# Epoch 56/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 4s 505ms/step - accuracy: 0.9961 - f1_score: 0.9408 - loss: 0.0166 - precision: 0.9961 - recall: 0.9961 - val_accuracy: 0.9468 - val_f1_score: 0.9408 - val_loss: 0.1929 - val_precision: 0.9468 - val_recall: 0.9468
# Epoch 57/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 22s 4s/step - accuracy: 0.9981 - f1_score: 0.9410 - loss: 0.0161 - precision: 0.9981 - recall: 0.9964 - val_accuracy: 0.9255 - val_f1_score: 0.9414 - val_loss: 0.2057 - val_precision: 0.9305 - val_recall: 0.9255
# Epoch 58/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 4s 493ms/step - accuracy: 1.0000 - f1_score: 0.9415 - loss: 0.0212 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9309 - val_f1_score: 0.9415 - val_loss: 0.2170 - val_precision: 0.9405 - val_recall: 0.9255
# Epoch 59/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 3s/step - accuracy: 0.9972 - f1_score: 0.9418 - loss: 0.0178 - precision: 0.9972 - recall: 0.9972 - val_accuracy: 0.9415 - val_f1_score: 0.9421 - val_loss: 0.1827 - val_precision: 0.9415 - val_recall: 0.9415
# Epoch 60/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 4s 495ms/step - accuracy: 0.9961 - f1_score: 0.9422 - loss: 0.0186 - precision: 0.9961 - recall: 0.9961 - val_accuracy: 0.9415 - val_f1_score: 0.9422 - val_loss: 0.2336 - val_precision: 0.9415 - val_recall: 0.9415
# Epoch 61/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 22s 4s/step - accuracy: 0.9972 - f1_score: 0.9425 - loss: 0.0146 - precision: 0.9972 - recall: 0.9957 - val_accuracy: 0.9415 - val_f1_score: 0.9428 - val_loss: 0.1981 - val_precision: 0.9412 - val_recall: 0.9362
# Epoch 62/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 4s 515ms/step - accuracy: 1.0000 - f1_score: 0.9429 - loss: 0.0098 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9255 - val_f1_score: 0.9429 - val_loss: 0.2268 - val_precision: 0.9255 - val_recall: 0.9255
# Epoch 63/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 3s/step - accuracy: 0.9989 - f1_score: 0.9431 - loss: 0.0117 - precision: 0.9989 - recall: 0.9980 - val_accuracy: 0.9574 - val_f1_score: 0.9435 - val_loss: 0.1446 - val_precision: 0.9626 - val_recall: 0.9574
# Epoch 64/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 4s 486ms/step - accuracy: 0.9922 - f1_score: 0.9436 - loss: 0.0155 - precision: 0.9922 - recall: 0.9922 - val_accuracy: 0.9309 - val_f1_score: 0.9436 - val_loss: 0.1906 - val_precision: 0.9358 - val_recall: 0.9309
# Epoch 65/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 4s/step - accuracy: 0.9995 - f1_score: 0.9438 - loss: 0.0095 - precision: 0.9995 - recall: 0.9985 - val_accuracy: 0.9362 - val_f1_score: 0.9441 - val_loss: 0.2030 - val_precision: 0.9412 - val_recall: 0.9362
# Epoch 66/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 4s 487ms/step - accuracy: 1.0000 - f1_score: 0.9442 - loss: 0.0095 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9521 - val_f1_score: 0.9442 - val_loss: 0.1551 - val_precision: 0.9521 - val_recall: 0.9521
# Epoch 67/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 22s 3s/step - accuracy: 0.9994 - f1_score: 0.9445 - loss: 0.0122 - precision: 0.9994 - recall: 0.9984 - val_accuracy: 0.9362 - val_f1_score: 0.9448 - val_loss: 0.2087 - val_precision: 0.9462 - val_recall: 0.9362
# Epoch 68/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 4s 492ms/step - accuracy: 0.9961 - f1_score: 0.9449 - loss: 0.0075 - precision: 0.9961 - recall: 0.9961 - val_accuracy: 0.9415 - val_f1_score: 0.9449 - val_loss: 0.1787 - val_precision: 0.9412 - val_recall: 0.9362
# Epoch 69/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 22s 3s/step - accuracy: 0.9983 - f1_score: 0.9451 - loss: 0.0105 - precision: 0.9983 - recall: 0.9983 - val_accuracy: 0.9255 - val_f1_score: 0.9454 - val_loss: 0.2110 - val_precision: 0.9305 - val_recall: 0.9255
# Epoch 70/70
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 477ms/step - accuracy: 0.9961 - f1_score: 0.9455 - loss: 0.0151 - precision: 0.9961 - recall: 0.9961 - val_accuracy: 0.9202 - val_f1_score: 0.9455 - val_loss: 0.2315 - val_precision: 0.9202 - val_recall: 0.9202

# %%
# Evaluate the model and unpack the returned values appropriately
test_loss, test_accuracy, test_precision, test_recall, test_f1_score = model.evaluate(validation_generator)

# Print the test accuracy
print(f"Test Accuracy: {test_accuracy * 100:.2f}%")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - accuracy: 0.9362 - f1_score: 0.9454 - loss: 0.2286 - precision: 0.9412 - recall: 0.9362
# Test Accuracy: 93.62%

# %%
# Plot training & validation accuracy
plt.plot(history.history['accuracy'], label='Train')
plt.plot(history.history['val_accuracy'], label='Validation')
plt.plot(fine_tune_history.history['accuracy'], label='Fine-Tune Train')
plt.plot(fine_tune_history.history['val_accuracy'], label='Fine-Tune Validation')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Training and Validation Accuracy')
plt.show()

# %%
# Plot training & validation loss
plt.plot(history.history['loss'], label='Train')
plt.plot(history.history['val_loss'], label='Validation')
plt.plot(fine_tune_history.history['loss'], label='Fine-Tune Train')
plt.plot(fine_tune_history.history['val_loss'], label='Fine-Tune Validation')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.title('Training and Validation Loss')
plt.show()

# %%
# Plot training & validation precision
plt.plot(history.history['precision'], label='Train')
plt.plot(history.history['val_precision'], label='Validation')
plt.plot(fine_tune_history.history['precision'], label='Fine-Tune Train')
plt.plot(fine_tune_history.history['val_precision'], label='Fine-Tune Validation')
plt.xlabel('Epochs')
plt.ylabel('Precision')
plt.legend()
plt.title('Training and Validation Precision')
plt.show()

# %%
# Plot training & validation recall
plt.plot(history.history['recall'], label='Train')
plt.plot(history.history['val_recall'], label='Validation')
plt.plot(fine_tune_history.history['recall'], label='Fine-Tune Train')
plt.plot(fine_tune_history.history['val_recall'], label='Fine-Tune Validation')
plt.xlabel('Epochs')
plt.ylabel('Recall')
plt.legend()
plt.title('Training and Validation Recall')
plt.show()

# %%
# Plot training & validation f1_score
plt.plot(history.history['f1_score'], label='Train')
plt.plot(history.history['val_f1_score'], label='Validation')
plt.plot(fine_tune_history.history['f1_score'], label='Fine-Tune Train')
plt.plot(fine_tune_history.history['val_f1_score'], label='Fine-Tune Validation')
plt.xlabel('Epochs')
plt.ylabel('F1_score')
plt.legend()
plt.title('Training and Validation F1_score')
plt.show()

# %%
import numpy as np
from tensorflow.keras.preprocessing import image
import os

# Define the path to the Basil folder
basil_folder_path = '/content/drive/My Drive/Pizza Topping Classification Project/Pizza_Classification_Dataset/test/Basil'

# Get a list of all image files in the Basil folder
image_files = [f for f in os.listdir(basil_folder_path) if os.path.isfile(os.path.join(basil_folder_path, f))]

# Define your pizza categories
pizza_categories = ['Basil', 'Mushroom', 'Pepperoni']

# Loop through each image file and make a prediction
for image_file in image_files:
    # Construct the full path to the image
    img_path = os.path.join(basil_folder_path, image_file)

    # Load and preprocess the image
    img = image.load_img(img_path, target_size=(224, 224))
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)
    img_array = preprocess_input(img_array)

    # Make the prediction
    prediction = model.predict(img_array)

    # Get the predicted class index and category label
    predicted_class_index = np.argmax(prediction)
    predicted_category = pizza_categories[predicted_class_index]

    # Print the prediction for the current image
    print(f"Image: {image_file}, Predicted category: {predicted_category}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 15s 15s/step
# Image: 00041_2e288952c8c5487385b422c992bcabf0.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Image: 00090_c716676519134b5c9939345770ccabc1.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Image: 00163_81917be87b6e4154b63d47bd0bc29fc1.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Image: 00202_77fd66d2451844aab1f27af3e360a6ba.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Image: 00167_d9243f9425ee49bdbcd42e26863acc63.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Image: 00035_8e450d7210014eadba06671977704a2a.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Image: 00115_86ff734cd14a41fdbe13da1aab281e4c.jpg, Predicted category: Pepperoni
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Image: 01453_e3ebea7c7b3e4c17a91b8c0ed0d6be71.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Image: 01205_94dba2062afa46fcaa29ebaf9f4b81d6.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Image: 00635_adb5f751efc34e6bae6fc4092fc85f45.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Image: 02006_e2c49016cbdf4b4693a3420963f57c44.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Image: 01436_73e260b9d659451aba1864d3cfd85fbc.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Image: 00507_4788b6e693d64d0a8f8e54f94aa693da.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Image: 01588_a5ca63ceb9dc4474b6bcdc3011e0aab3.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Image: 01574_c5f047dd17394ed0890b45b9ee4a7006.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Image: 01565_94063eb15da54d958831f7055b16e4aa.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Image: 02201_87b58dcd92a44a4c8a6f875c795bc89d.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Image: 01384_84332c3d849e4d4088d98c15ff2a293a.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Image: 02355_ab5d63d40f5043668c8896f5b43c00fd.jpg, Predicted category: Pepperoni
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Image: 00680_e71b6aaf4f914e27b4121ff580e6bde8.jpg, Predicted category: Pepperoni
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Image: 00774_ebda82434c29456bbb0ded6eddce264b.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Image: 00738_3282df2313c84f4497bfca8e031087d4.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Image: 01614_40e9d165aaef4b36adb7628aaf522f05.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Image: 00957_bc9d0c194f6943c28389409ee28c59ea.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Image: 00321_6c9a3d8f3e71472c9cc0d1e3d5a439d6.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Image: 01765_5dd866da5f4340638e07a21e1460c7ed.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Image: 00373_fe5a86807c2c46b3a2c7013f68736e4b.jpg, Predicted category: Pepperoni
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Image: 00669_22e993930a3b4a23ace513a4d2b0ce95.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Image: 00764_d2791f2a268343618f4369bec2a141de.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Image: 01049_65566d3df6974d9799cb6a5b433da76f.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Image: 02131_e53f95926dff4dabb2c68b838f6bee15.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Image: 02357_c607e48590ea46ce86704f3194542c7b.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Image: 00229_8222899d37204579818671ebc67b45a1.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Image: 01272_e859c2af6024491ca3699eb2ae983e95.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Image: 01147_fdde02e5cf584b7d998908e1ce8e9d76.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Image: 00371_87d8f85cdd8942a3844bc7b80b95daf1.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Image: 01759_bf48cfeac904459088569aff1089cb8f.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Image: 00598_c49b623e7b78481cbe8f81232040e676.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Image: 01777_bd34b5037cd54675b840801eaa2446c1.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Image: 00624_0681bd6cf11c41cfbaa5e6b01c75dff0.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Image: 02541_cd2c876297fb4f328036d3317e3142e2.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Image: 02591_4e7e63b56d384f8499106411b4cfbf80.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Image: 01963_b1368cbfadc1411da3ee55dc60459335.jpg, Predicted category: Mushroom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Image: 01828_b64a8a7bbda4456582c0fa56ff675234.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Image: 00567_4b5a65b250234da0821f506bdb7052ca.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Image: 01431_8ebc1e169a6f486688c4ee6af0e7a5a0.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Image: 01629_47a2c2b437c144abb1e96c7cf95be077.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Image: 01320_11c1f11aaa54425ba8cf483d9d432189.jpg, Predicted category: Pepperoni
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Image: 02858_b1e12f6d861248b5ad1f21494c372649.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Image: 01473_03761e147cff42cb86a614637346130e.jpg, Predicted category: Pepperoni
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Image: 00208_a66294beb5e14aeb84aba26e454b3bb0.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Image: 00591_94ab9d5006464fd3b41af5ff8bf9fe32.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Image: 01089_a6f31848239b4a48a83c4f175b5fda02.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Image: 02776_b502c9d79bad441db0a11f05511021b6.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Image: 01367_32660686165a4c71b1027d2efd89ab81.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Image: 00277_c55346f483e44fd69dc5a5b5191383cb.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Image: 01656_05a6bba5375e4427978e3952b8af8cc8.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Image: 02111_9bb26be1ee66494b9035588add16562b.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Image: 00672_c69d0e0941aa4e1baab00579b26e119d.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Image: 01798_f4912aa74eb94b73b3110c9b46341177.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Image: 02641_4f3a51902a274abaa6609dff1e183df2.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Image: 00744_cc7fd60b70504880bdffbc9182419865.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Image: 01617_22ea3badd3484d258b5bbb256fdb519c.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Image: 00752_1acec9bbbf1d4407b07dc87651012c4d.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Image: 03957_e43fb5ba5cc3471c946cd10c5cab155d.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Image: 04476_9463cf1a81ce4c15a2a38c80b5fac212.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Image: 06193_e360d0019b784710bd6feaec9964fb2f.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Image: 03933_34a9ddb4deb14a38b4d75b0eea27b9b5.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Image: 04098_5e230a62c9184d26b81cb430270c52f0.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Image: 05886_743055f8345b4d5ca8b641441eee8aa1.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Image: 02894_564b8f97bb9b459bbd647e7e7178dd47.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Image: 02887_53d123aaa05d48f19821dc76b4184cfb.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Image: 03009_f27addb927124adc914bb370151d94f0.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Image: 02885_15d94dae4b60461499b974c9187c6761.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Image: 03083_f34fa08c6be74f3ab2329fa392d8d5bf.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Image: 06045_cf1c38d39a1e4df1acb429dd656e5485.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Image: 03092_66e2c0ceac4a4eefb1ef1fac695342cf.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Image: 06423_585cdb73914c4924a69d0a9cf600dd77.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Image: 04566_4298d6aa071c424c8bf9b3cce792f8e4.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Image: 05422_aec5b41bc4b049aca7d891de5a0037e2.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Image: 05613_f76a932113b041398911ec712a543dca.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Image: 05214_a9a2d7c4be864224a512b16d156d3462.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Image: 02863_a9bf6c7c729f4b12a3619c3769fe0e98.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Image: 05550_67f130c5ac8b4d95a396fc309388ecd6.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Image: 04085_4e64ca7f150047cc8300940a66dcb748.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Image: 06012_057d0aa3884b4dd39f72404bc9b86c94.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Image: 04924_86e6e40b1c9942318e9742dfa0fe6e9d.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Image: 04148_d07c270b77784a7f8eaa3374b8f54b97.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Image: 04292_5ed2b0a90ccd4db19daacda99a390135.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Image: 06361_fa4a7d2844a94b97aaafa6feb0a67e13.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Image: 04568_969def6eb88149cbb0fbef9c8b48e944.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Image: 06177_93f2ae5434a54aaca53e1824ff7a9f91.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Image: 05644_a4804d955ccd438a97483c90a984db58.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Image: 04069_1b41dc0b6d274c14ba1c0dc8078bce43.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Image: 05321_637e50d2f3884f95a0387d52523fe5e6.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Image: 05949_8d0249cdda184122ab774f10294bd512.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Image: 06287_bc5a5e4c718b4c39bd75202b88b91bb0.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Image: 03120_fdbc1ed6cf604f4f9cfad2a9de8cf45e.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Image: 06189_4d0400819013442aab926b1bb3f801d5.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Image: 06398_7f8897cca5c740d790aca2152c8f2373.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Image: 03888_9cc1b1cecd184c51b9d69368924b026a.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Image: 02892_d3ded3c345f34078af84b345536df1c7.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Image: 04593_64cff07edef74b2393a51257d0b49697.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Image: 06523_1986613a2f0043bbaa8fd06f781a4688.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Image: 05684_91f9327e437d42b3ba73f86f365e3958.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Image: 05438_92e1c382058f42bfae0974e57a95df17.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# Image: 04485_13bd1709d5b74f30bfda271d9e489c91.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Image: 05142_ed4190bc7691477c90c7f05dd7c129aa.jpg, Predicted category: Pepperoni
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Image: 05350_2cd8669700d64d178d4ff7ec4a4f1118.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Image: 04386_082ff5bd996d49febc2071b1284eaf08.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Image: 04309_212c931b9a94442dbba17cbbe82b1d60.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Image: 05145_fecd56534a9d4275a07e2caab188ad7f.jpg, Predicted category: Pepperoni
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Image: 04778_f7892a3ad83b49ff8896aadf0ffea00a.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Image: 05348_27cafa9947e94ad6a06ee529ccc8dd8a.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Image: 02954_5388e8c9f9c14733a09a3944c70a5e46.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Image: 05285_bdb05a2e24ee41e6942bbd3085635ef2.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Image: 05576_9a6cdc7859cb483fb5899a735344c101.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Image: 07727_a4b2ae22beca470ebf4fd63d76433c97.jpg, Predicted category: Pepperoni
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Image: 08497_08740449c8c745b9b6b74a3832b0941c.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Image: 06659_d9c103f5c15c47c5a2f96588c03579f2.jpg, Predicted category: Mushroom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Image: 07830_54557539c4aa45b99532c40c497e2e2a.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Image: 06765_1f36293b7ee9437b80e4ebbffec69ed3.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Image: 08480_c475efd30c85405298186d383c9f5133.jpg, Predicted category: Pepperoni
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Image: 08882_606baf8425f1474f98a6f74f658697bb.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Image: 08654_a73bc433018e42b38dac71d4608f1c1f.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Image: 07005_00fc4a17f1be4e6981053bed065dfeb2.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Image: 07231_c23bf1c8c8c5488186fa71f20fa404cf.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Image: 07824_d2b003f9fcf54f9585d514ac9e13bb51.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Image: 07656_339ce52b38364f379ba164851354ddf3.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Image: 07996_5a5cfbe4e0e24f1bbf20e7cac662f5ba.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Image: 08372_fc21184f4342434ead58af7a92b26adb.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Image: 06537_8a57425da581471387cc551f71f9f9f6.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Image: 08683_d1e91aad60024be0b4b44a790460018d.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Image: 07723_c8320ac834744923963da7561f49198f.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Image: 06957_0f30b1c7b9db447bb97ae5eef93384ca.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Image: 08485_fa9269377c344e649ce1ad52b2525c1b.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Image: 06964_13ef9efdf33f42fa87da700837b8e5e8.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Image: 08505_a2226970c80d4133ba6b4f33d923741b.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Image: 06583_1c94496d6a3d4d75b42fe7fb673877fb.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Image: 06715_62e858a2a7304dafb762c83a296b798c.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Image: 07846_b026f8b18c58408a9d245ad94076ee98.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Image: 06927_ec613f950caa45f4a14b0a31b0f25ca7.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Image: 07400_d4d26b17aff24de6a65aadb75eff5ec2.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Image: 07155_dd7538c85f264c2995181ccccf275d89.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Image: 08206_9529d27b1e894e998f30d8d3347c939f.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Image: 07740_14719574dc5940129acf4d4fba87dc6b.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Image: 07508_a7f656eb956741aea98c04f0389654b8.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Image: 07636_350f24d5b348464685ee49cf5b6b6673.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Image: 07549_148ab5eef11c4bafa46ff4b741cfdf2e.jpg, Predicted category: Basil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Image: 08914_0b3d3e05b33a4a68bb93c984bb03dea3.jpg, Predicted category: Basil

# %%
import numpy as np
import os
from tensorflow.keras.preprocessing import image
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Define your pizza categories
pizza_categories = ['Basil', 'Mushroom', 'Pepperoni']

# Initialize empty lists to store all predicted and true categories
all_predicted_categories = []
all_true_categories = []

# Loop through each pizza category
for category in pizza_categories:
    # Define the path to the category folder
    category_folder_path = os.path.join('/content/drive/My Drive/Pizza Topping Classification Project/Pizza_Classification_Dataset/test', category)

    # Get a list of all image files in the category folder
    image_files = [f for f in os.listdir(category_folder_path) if os.path.isfile(os.path.join(category_folder_path, f))]

    # Loop through each image file and make a prediction
    for image_file in image_files:
        # Construct the full path to the image
        img_path = os.path.join(category_folder_path, image_file)

        # Load and preprocess the image
        img = image.load_img(img_path, target_size=(224, 224))
        img_array = image.img_to_array(img)
        img_array = np.expand_dims(img_array, axis=0)
        img_array = preprocess_input(img_array)

        # Make the prediction
        prediction = model.predict(img_array)

        # Get the predicted class index and category label
        predicted_class_index = np.argmax(prediction)
        predicted_category = pizza_categories[predicted_class_index]

        # Append the predicted and true categories to the lists
        all_predicted_categories.append(predicted_category)
        all_true_categories.append(category)  # True category is the current category

# Convert the lists to NumPy arrays
all_predicted_categories = np.array(all_predicted_categories)
all_true_categories = np.array(all_true_categories)

# Create the confusion matrix
cm_all_categories = confusion_matrix(all_true_categories, all_predicted_categories, labels=pizza_categories)

# Plot the confusion matrix using Seaborn
plt.figure(figsize=(10, 8))
sns.heatmap(cm_all_categories, annot=True, fmt="d", cmap="Blues", cbar=False,
            xticklabels=pizza_categories, yticklabels=pizza_categories)
plt.title("Confusion Matrix for ConvNeXtBase Model")
plt.xlabel("Predicted Category")
plt.ylabel("True Category")
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step

# %%
import numpy as np
import os
from tensorflow.keras.preprocessing import image
from sklearn.metrics import confusion_matrix
from tensorflow.keras.applications.convnext import preprocess_input

# Define pizza categories
pizza_categories = ['Basil', 'Mushroom', 'Pepperoni']

# Path to your Test folder
test_folder_path = '/content/drive/My Drive/Pizza Topping Classification Project/Pizza_Classification_Dataset/test'

true_labels = []
predicted_labels = []

# Loop through each pizza category folder in the Test folder
for category_index, category in enumerate(pizza_categories):
    category_folder_path = os.path.join(test_folder_path, category)

    # Loop through images in the category folder
    for image_file in os.listdir(category_folder_path):
        img_path = os.path.join(category_folder_path, image_file)
        img = image.load_img(img_path, target_size=(224, 224))
        img_array = image.img_to_array(img)
        img_array = np.expand_dims(img_array, axis=0)
        img_array = preprocess_input(img_array)

        # Make prediction
        prediction = model.predict(img_array)
        predicted_class_index = np.argmax(prediction)

        # Append labels
        true_labels.append(category_index)  # Use category_index for true label
        predicted_labels.append(predicted_class_index)

# Calculate confusion matrix
cm = confusion_matrix(true_labels, predicted_labels, labels=range(len(pizza_categories)))

# Print TP, FP, TN, FN for each category
for category_index, category in enumerate(pizza_categories):
    TP = cm[category_index, category_index]
    FP = sum(cm[i, category_index] for i in range(len(pizza_categories)) if i != category_index)
    FN = sum(cm[category_index, i] for i in range(len(pizza_categories)) if i != category_index)
    TN = sum(cm[i, j] for i in range(len(pizza_categories)) for j in range(len(pizza_categories)) if i != category_index and j != category_index)

    print(f"For {category} Category:")
    print("True Positives (TP):", TP)
    print("False Positives (FP):", FP)
    print("True Negatives (TN):", TN)
    print("False Negatives (FN):", FN)
    print("-" * 20)  # Separator between categories
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# For Basil Category:
# True Positives (TP): 138
# False Positives (FP): 19
# True Negatives (TN): 304
# False Negatives (FN): 12
# --------------------
# For Mushroom Category:
# True Positives (TP): 53
# False Positives (FP): 7
# True Negatives (TN): 405
# False Negatives (FN): 8
# --------------------
# For Pepperoni Category:
# True Positives (TP): 241
# False Positives (FP): 15
# True Negatives (TN): 196
# False Negatives (FN): 21
# --------------------

# %%
from tensorflow.keras.applications.convnext import preprocess_input
import numpy as np
import os
from tensorflow.keras.preprocessing import image
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

# Define pizza categories
pizza_categories = ['Basil', 'Mushroom', 'Pepperoni']

# Path to your Test folder
test_folder_path = '/content/drive/My Drive/Pizza Topping Classification Project/Pizza_Classification_Dataset/test'

# Initialize lists to store true and predicted probabilities for each class
true_labels = []
predicted_probabilities = []

# Loop through each pizza category folder in the Test folder
for category_index, category in enumerate(pizza_categories):
    category_folder_path = os.path.join(test_folder_path, category)

    # Loop through images in the category folder
    for image_file in os.listdir(category_folder_path):
        img_path = os.path.join(category_folder_path, image_file)
        img = image.load_img(img_path, target_size=(224, 224))
        img_array = image.img_to_array(img)
        img_array = np.expand_dims(img_array, axis=0)
        img_array = preprocess_input(img_array)

        # Make prediction (get probabilities)
        prediction = model.predict(img_array)[0]  # Get probabilities for all classes

        # Append true label (one-hot encoded) and predicted probabilities
        true_label = np.zeros(len(pizza_categories))
        true_label[category_index] = 1  # One-hot encoding
        true_labels.append(true_label)
        predicted_probabilities.append(prediction)

# Convert lists to NumPy arrays
true_labels = np.array(true_labels)
predicted_probabilities = np.array(predicted_probabilities)

# Plot ROC curves for each class
plt.figure(figsize=(10, 8))
for i in range(len(pizza_categories)):
    fpr, tpr, _ = roc_curve(true_labels[:, i], predicted_probabilities[:, i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, label=f'{pizza_categories[i]}')

plt.plot([0, 1], [0, 1], 'k--')  # Diagonal line for random classifier
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curves')
plt.legend(loc="lower right")
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step

# %%
model.save('/content/drive/My Drive/Pizza Topping Classification Project/Pizza_Topping_Classification_ConvNeXtbase.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
# !pip install tf-keras-vis
# Out:
# Requirement already satisfied: tf-keras-vis in /usr/local/lib/python3.11/dist-packages (0.8.7)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from tf-keras-vis) (1.13.1)
# Requirement already satisfied: pillow in /usr/local/lib/python3.11/dist-packages (from tf-keras-vis) (11.1.0)
# Requirement already satisfied: deprecated in /usr/local/lib/python3.11/dist-packages (from tf-keras-vis) (1.2.18)
# Requirement already satisfied: imageio in /usr/local/lib/python3.11/dist-packages (from tf-keras-vis) (2.37.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tf-keras-vis) (24.2)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.11/dist-packages (from deprecated->tf-keras-vis) (1.17.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from imageio->tf-keras-vis) (1.26.4)

# %%
from tf_keras_vis.gradcam import Gradcam
from tf_keras_vis.utils import normalize
from tensorflow.keras.preprocessing import image
import numpy as np
import matplotlib.pyplot as plt
import os
import random
from tensorflow.keras.applications.convnext import preprocess_input
from tensorflow.keras.layers import Conv2D, DepthwiseConv2D

def find_last_conv_layer(model):
    """Finds the last convolutional layer in the model."""
    conv_layers = []
    for layer in model.layers:
      if isinstance(layer, (Conv2D, DepthwiseConv2D)):
        conv_layers.append(layer)
    if not conv_layers:
        raise ValueError("No convolutional layers found in the model.")
    return conv_layers[-1].name


def grad_cam_heatmap(model, image, layer_name=None):
    """Generates a Grad-CAM heatmap. If layer_name is None, the last conv layer will be used"""
    if layer_name is None:
        layer_name = find_last_conv_layer(model)

    gradcam = Gradcam(model, clone=False)

    def loss(output):
        predicted_class = np.argmax(model.predict(image))
        return output[:, predicted_class]

    cam = gradcam(loss, image, penultimate_layer=layer_name)
    cam = normalize(cam)
    return cam

# Define pizza categories
pizza_categories = ['Basil', 'Mushroom', 'Pepperoni']

data_path = '/content/drive/My Drive/Pizza Topping Classification Project/Pizza_Classification_Dataset/test'

# Loop through each pizza category
for category in pizza_categories:
    print(f"Processing category: {category}")
    category_path = os.path.join(data_path, category)
    img_names = os.listdir(category_path)

    if len(img_names) < 3:
        print(f"Skipping {category}, not enough images.")
        continue

    img_paths = random.sample([os.path.join(category_path, img) for img in img_names], 3)

    # Process 3 randomly selected images per category
    for img_path in img_paths:
        img = image.load_img(img_path, target_size=(224, 224))
        x = image.img_to_array(img)
        x = np.expand_dims(x, axis=0)
        x = preprocess_input(x)

        heatmap = grad_cam_heatmap(model, x)
        heatmap = np.uint8(255 * heatmap[0])

        fig, axes = plt.subplots(1, 2, figsize=(10, 5))

        axes[0].imshow(img)
        axes[0].set_title("Original Image")
        axes[0].axis('off')

        axes[1].imshow(img)
        axes[1].imshow(heatmap, cmap='jet', alpha=0.5)
        predicted_category = pizza_categories[np.argmax(model.predict(x))]
        axes[1].set_title(f"Predicted Category: {predicted_category}")
        axes[1].axis('off')

        plt.tight_layout()
        plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
from tf_keras_vis.gradcam_plus_plus import GradcamPlusPlus
from tf_keras_vis.utils import normalize
from tensorflow.keras.preprocessing import image
import numpy as np
import matplotlib.pyplot as plt
import os
from tensorflow.keras.applications.convnext import preprocess_input
from tensorflow.keras.layers import Conv2D, DepthwiseConv2D


def find_last_conv_layer(model):
    """Finds the last convolutional layer in the model."""
    conv_layers = []
    for layer in model.layers:
      if isinstance(layer, (Conv2D, DepthwiseConv2D)):
        conv_layers.append(layer)
    if not conv_layers:
        raise ValueError("No convolutional layers found in the model.")
    return conv_layers[-1].name


def grad_cam_plus_plus_heatmap(model, image, layer_name=None):
    """Generates a Grad-CAM++ heatmap. If layer_name is None, the last conv layer will be used"""
    if layer_name is None:
        layer_name = find_last_conv_layer(model)

    gradcam_plus_plus = GradcamPlusPlus(model, clone=False)

    def loss(output):
        predicted_class = np.argmax(model.predict(image))
        return output[:, predicted_class]

    cam = gradcam_plus_plus(loss, image, penultimate_layer=layer_name)
    cam = normalize(cam)
    return cam

# Define pizza categories
pizza_categories = ['Basil', 'Mushroom', 'Pepperoni']

# Modified Grad-CAM++ Visualization for random images from Test folder
data_path = '/content/drive/My Drive/Pizza Topping Classification Project/Pizza_Classification_Dataset/test'

# Loop through each pizza category
for category in pizza_categories:
    print(f"Processing category: {category}")
    category_path = os.path.join(data_path, category)
    img_names = os.listdir(category_path)

    if len(img_names) < 3:
        print(f"Skipping {category}, not enough images.")
        continue

    img_paths = random.sample([os.path.join(category_path, img) for img in img_names], 3)

    # Process 3 randomly selected images per category
    for img_path in img_paths:
        img = image.load_img(img_path, target_size=(224, 224))
        x = image.img_to_array(img)
        x = np.expand_dims(x, axis=0)
        x = preprocess_input(x)

        heatmap = grad_cam_plus_plus_heatmap(model, x)
        heatmap = np.uint8(255 * heatmap[0])

        fig, axes = plt.subplots(1, 2, figsize=(10, 5))

        axes[0].imshow(img)
        axes[0].set_title("Original Image")
        axes[0].axis('off')

        axes[1].imshow(img)
        axes[1].imshow(heatmap, cmap='jet', alpha=0.5)
        predicted_category = pizza_categories[np.argmax(model.predict(x))]
        axes[1].set_title(f"Predicted Category: {predicted_category}")
        axes[1].axis('off')

        plt.tight_layout()
        plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.
